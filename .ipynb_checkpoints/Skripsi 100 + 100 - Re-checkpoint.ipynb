# %%
import pandas as pd 
import numpy as np
import string 
import re 
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# %% [markdown]
# # Baca DataFrame dari dataset_komentar_instragram_cyberbulling.csv

# %%
df = pd.read_excel('versi 4.0.2.xlsx')

# %%
df
# Out:
#      Sentiment                                            content  score  \
# 0     Negative  Biasanya saya scan QR code di lobby kantor set...      1
# 1     Negative  Setelah di-update versi terbaru kok malah gak ...      1
# 2     Negative  Sekarang Update terbaru malah ga bisa masuk ad...      1
# 3     Negative  Gimana ini aplikasi kok gak bisa di gunakan. S...      1
# 4     Negative  Sebelumnya ada pilihan warga negara, saya suda...      1
# ...        ...                                                ...    ...
# 1943  Negative                               aku gak bis masuknya      5
# 1944  Negative                                  Ko gx bisa login.      5
# 1945  Negative                                 Koq gak mau kebuka      5
# 1946  Positive                                 Semoga sehat semua      5
# 1947  Positive                                sangat membantu,, 👍      5
#
#      reviewCreatedVersion
# 0                   4.0.2
# 1                   4.0.2
# 2                   4.0.2
# 3                   4.0.2
# 4                   4.0.2
# ...                   ...
# 1943                4.0.2
# 1944                4.0.2
# 1945                4.0.2
# 1946                4.0.2
# 1947                4.0.2
#
# [1948 rows x 4 columns]

# %%
df_skripsi = df.drop(['score','reviewCreatedVersion'],axis = 1)

# %%
df_skripsi
# Out:
#      Sentiment                                            content
# 0     Negative  Biasanya saya scan QR code di lobby kantor set...
# 1     Negative  Setelah di-update versi terbaru kok malah gak ...
# 2     Negative  Sekarang Update terbaru malah ga bisa masuk ad...
# 3     Negative  Gimana ini aplikasi kok gak bisa di gunakan. S...
# 4     Negative  Sebelumnya ada pilihan warga negara, saya suda...
# ...        ...                                                ...
# 1943  Negative                               aku gak bis masuknya
# 1944  Negative                                  Ko gx bisa login.
# 1945  Negative                                 Koq gak mau kebuka
# 1946  Positive                                 Semoga sehat semua
# 1947  Positive                                sangat membantu,, 👍
#
# [1948 rows x 2 columns]

# %% [markdown]
# # Mendeteksi Positif & Negatif

# %%
df_skripsi.Sentiment.value_counts()
# Out:
# Negative    1467
# Positive     481
# Name: Sentiment, dtype: int64

# %% [markdown]
# # Menampilkan Bagian kolom pada data

# %%
df_skripsi.columns = ['label','text']

# %%
df_skripsi['text_real'] = df_skripsi.text

# %% [markdown]
# # Menampilkan DataFrame

# %%
df_skripsi
# Out:
#          label                                               text  \
# 0     Negative  Biasanya saya scan QR code di lobby kantor set...
# 1     Negative  Setelah di-update versi terbaru kok malah gak ...
# 2     Negative  Sekarang Update terbaru malah ga bisa masuk ad...
# 3     Negative  Gimana ini aplikasi kok gak bisa di gunakan. S...
# 4     Negative  Sebelumnya ada pilihan warga negara, saya suda...
# ...        ...                                                ...
# 1943  Negative                               aku gak bis masuknya
# 1944  Negative                                  Ko gx bisa login.
# 1945  Negative                                 Koq gak mau kebuka
# 1946  Positive                                 Semoga sehat semua
# 1947  Positive                                sangat membantu,, 👍
#
#                                               text_real
# 0     Biasanya saya scan QR code di lobby kantor set...
# 1     Setelah di-update versi terbaru kok malah gak ...
# 2     Sekarang Update terbaru malah ga bisa masuk ad...
# 3     Gimana ini aplikasi kok gak bisa di gunakan. S...
# 4     Sebelumnya ada pilihan warga negara, saya suda...
# ...                                                 ...
# 1943                               aku gak bis masuknya
# 1944                                  Ko gx bisa login.
# 1945                                 Koq gak mau kebuka
# 1946                                 Semoga sehat semua
# 1947                                sangat membantu,, 👍
#
# [1948 rows x 3 columns]

# %% [markdown]
# # Mengubah Huruf menjadi kecil

# %%
df_skripsi['text'] = df_skripsi['text'].str.lower()
print('Case Folding Result : \n')
print(df_skripsi['text'].head(5))
print('\n\n\n')
# Out:
# Case Folding Result :
#
# 0    biasanya saya scan qr code di lobby kantor set...
# 1    setelah di-update versi terbaru kok malah gak ...
# 2    sekarang update terbaru malah ga bisa masuk ad...
# 3    gimana ini aplikasi kok gak bisa di gunakan. s...
# 4    sebelumnya ada pilihan warga negara, saya suda...
# Name: text, dtype: object

# %% [markdown]
# # Menghapus special karakter dan url

# %%
def remove_text_special(text):
    # hapus tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # hapus non ASCII (emot, bahasa china dll)
    text = text.encode('ascii', 'replace').decode('ascii')
    # hapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove URL 
    return text.replace("http://", " ").replace("https://", " ")
df_skripsi['text'] = df_skripsi.text.astype('str')                
df_skripsi['text'] = df_skripsi['text'].apply(remove_text_special)

# %%
df_skripsi
# Out:
#          label                                               text  \
# 0     Negative  biasanya saya scan qr code di lobby kantor set...
# 1     Negative  setelah di-update versi terbaru kok malah gak ...
# 2     Negative  sekarang update terbaru malah ga bisa masuk ad...
# 3     Negative  gimana ini aplikasi kok gak bisa di gunakan. s...
# 4     Negative  sebelumnya ada pilihan warga negara, saya suda...
# ...        ...                                                ...
# 1943  Negative                               aku gak bis masuknya
# 1944  Negative                                  ko gx bisa login.
# 1945  Negative                                 koq gak mau kebuka
# 1946  Positive                                 semoga sehat semua
# 1947  Positive                                sangat membantu,, ?
#
#                                               text_real
# 0     Biasanya saya scan QR code di lobby kantor set...
# 1     Setelah di-update versi terbaru kok malah gak ...
# 2     Sekarang Update terbaru malah ga bisa masuk ad...
# 3     Gimana ini aplikasi kok gak bisa di gunakan. S...
# 4     Sebelumnya ada pilihan warga negara, saya suda...
# ...                                                 ...
# 1943                               aku gak bis masuknya
# 1944                                  Ko gx bisa login.
# 1945                                 Koq gak mau kebuka
# 1946                                 Semoga sehat semua
# 1947                                sangat membantu,, 👍
#
# [1948 rows x 3 columns]

# %% [markdown]
# # Menghapus elongasi

# %%
#remove kata yang sengaja dipanjangkan
# seperti bisaaaaaaa -> bisa
def spell(word):
    if re.search(r'([a-zA-Z])\1{2,}', word):
        rword = re.sub(r'([a-zA-Z])\1{2,}','\\1', word)
        return rword
    else:
        return word
df_skripsi['text'] = df_skripsi['text'].apply(spell)

# %%
df_skripsi
# Out:
#          label                                               text  \
# 0     Negative  biasanya saya scan qr code di lobby kantor set...
# 1     Negative  setelah di-update versi terbaru kok malah gak ...
# 2     Negative  sekarang update terbaru malah ga bisa masuk ad...
# 3     Negative  gimana ini aplikasi kok gak bisa di gunakan. s...
# 4     Negative  sebelumnya ada pilihan warga negara, saya suda...
# ...        ...                                                ...
# 1943  Negative                               aku gak bis masuknya
# 1944  Negative                                  ko gx bisa login.
# 1945  Negative                                 koq gak mau kebuka
# 1946  Positive                                 semoga sehat semua
# 1947  Positive                                sangat membantu,, ?
#
#                                               text_real
# 0     Biasanya saya scan QR code di lobby kantor set...
# 1     Setelah di-update versi terbaru kok malah gak ...
# 2     Sekarang Update terbaru malah ga bisa masuk ad...
# 3     Gimana ini aplikasi kok gak bisa di gunakan. S...
# 4     Sebelumnya ada pilihan warga negara, saya suda...
# ...                                                 ...
# 1943                               aku gak bis masuknya
# 1944                                  Ko gx bisa login.
# 1945                                 Koq gak mau kebuka
# 1946                                 Semoga sehat semua
# 1947                                sangat membantu,, 👍
#
# [1948 rows x 3 columns]

# %% [markdown]
# # menghapus tanda baca

# %%
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

df_skripsi['text'] = df_skripsi['text'].apply(remove_punctuation)

# %%
df_skripsi
# Out:
#          label                                               text  \
# 0     Negative  biasanya saya scan qr code di lobby kantor set...
# 1     Negative  setelah diupdate versi terbaru kok malah gak b...
# 2     Negative  sekarang update terbaru malah ga bisa masuk ad...
# 3     Negative  gimana ini aplikasi kok gak bisa di gunakan sa...
# 4     Negative  sebelumnya ada pilihan warga negara saya sudah...
# ...        ...                                                ...
# 1943  Negative                               aku gak bis masuknya
# 1944  Negative                                   ko gx bisa login
# 1945  Negative                                 koq gak mau kebuka
# 1946  Positive                                 semoga sehat semua
# 1947  Positive                                   sangat membantu
#
#                                               text_real
# 0     Biasanya saya scan QR code di lobby kantor set...
# 1     Setelah di-update versi terbaru kok malah gak ...
# 2     Sekarang Update terbaru malah ga bisa masuk ad...
# 3     Gimana ini aplikasi kok gak bisa di gunakan. S...
# 4     Sebelumnya ada pilihan warga negara, saya suda...
# ...                                                 ...
# 1943                               aku gak bis masuknya
# 1944                                  Ko gx bisa login.
# 1945                                 Koq gak mau kebuka
# 1946                                 Semoga sehat semua
# 1947                                sangat membantu,, 👍
#
# [1948 rows x 3 columns]

# %% [markdown]
# # menghapus enter tab

# %%
#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df_skripsi['text'] = df_skripsi['text'].apply(remove_whitespace_LT)

# %%
df_skripsi
# Out:
#          label                                               text  \
# 0     Negative  biasanya saya scan qr code di lobby kantor set...
# 1     Negative  setelah diupdate versi terbaru kok malah gak b...
# 2     Negative  sekarang update terbaru malah ga bisa masuk ad...
# 3     Negative  gimana ini aplikasi kok gak bisa di gunakan sa...
# 4     Negative  sebelumnya ada pilihan warga negara saya sudah...
# ...        ...                                                ...
# 1943  Negative                               aku gak bis masuknya
# 1944  Negative                                   ko gx bisa login
# 1945  Negative                                 koq gak mau kebuka
# 1946  Positive                                 semoga sehat semua
# 1947  Positive                                    sangat membantu
#
#                                               text_real
# 0     Biasanya saya scan QR code di lobby kantor set...
# 1     Setelah di-update versi terbaru kok malah gak ...
# 2     Sekarang Update terbaru malah ga bisa masuk ad...
# 3     Gimana ini aplikasi kok gak bisa di gunakan. S...
# 4     Sebelumnya ada pilihan warga negara, saya suda...
# ...                                                 ...
# 1943                               aku gak bis masuknya
# 1944                                  Ko gx bisa login.
# 1945                                 Koq gak mau kebuka
# 1946                                 Semoga sehat semua
# 1947                                sangat membantu,, 👍
#
# [1948 rows x 3 columns]

# %% [markdown]
# # menghapus spasi yang terlalu banyak

# %%
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df_skripsi['text'] = df_skripsi['text'].apply(remove_whitespace_multiple)

# %% [markdown]
# # menghapus karakter single seperti a b c d

# %%
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df_skripsi['text'] = df_skripsi['text'].apply(remove_singl_char)

# %%
df_skripsi
# Out:
#          label                                               text  \
# 0     Negative  biasanya saya scan qr code di lobby kantor set...
# 1     Negative  setelah diupdate versi terbaru kok malah gak b...
# 2     Negative  sekarang update terbaru malah ga bisa masuk ad...
# 3     Negative  gimana ini aplikasi kok gak bisa di gunakan sa...
# 4     Negative  sebelumnya ada pilihan warga negara saya sudah...
# ...        ...                                                ...
# 1943  Negative                               aku gak bis masuknya
# 1944  Negative                                   ko gx bisa login
# 1945  Negative                                 koq gak mau kebuka
# 1946  Positive                                 semoga sehat semua
# 1947  Positive                                    sangat membantu
#
#                                               text_real
# 0     Biasanya saya scan QR code di lobby kantor set...
# 1     Setelah di-update versi terbaru kok malah gak ...
# 2     Sekarang Update terbaru malah ga bisa masuk ad...
# 3     Gimana ini aplikasi kok gak bisa di gunakan. S...
# 4     Sebelumnya ada pilihan warga negara, saya suda...
# ...                                                 ...
# 1943                               aku gak bis masuknya
# 1944                                  Ko gx bisa login.
# 1945                                 Koq gak mau kebuka
# 1946                                 Semoga sehat semua
# 1947                                sangat membantu,, 👍
#
# [1948 rows x 3 columns]

# %% [markdown]
# # Membuat kolom text_token berisi kumpulan kata kata yang dipisah dengan koma

# %%
df_skripsi = df_skripsi.drop_duplicates()
df_skripsi = df_skripsi[['text_real','text','label']]
df_skripsi['text'] = df_skripsi['text'].str.lower()

def word_tokenize_wrapper(text):
    return word_tokenize(text)

df_skripsi['text_tokens'] = df_skripsi['text'].apply(word_tokenize_wrapper)

# %%
df_skripsi
# Out:
#                                               text_real  \
# 0     Biasanya saya scan QR code di lobby kantor set...
# 1     Setelah di-update versi terbaru kok malah gak ...
# 2     Sekarang Update terbaru malah ga bisa masuk ad...
# 3     Gimana ini aplikasi kok gak bisa di gunakan. S...
# 4     Sebelumnya ada pilihan warga negara, saya suda...
# ...                                                 ...
# 1943                               aku gak bis masuknya
# 1944                                  Ko gx bisa login.
# 1945                                 Koq gak mau kebuka
# 1946                                 Semoga sehat semua
# 1947                                sangat membantu,, 👍
#
#                                                    text     label  \
# 0     biasanya saya scan qr code di lobby kantor set...  Negative
# 1     setelah diupdate versi terbaru kok malah gak b...  Negative
# 2     sekarang update terbaru malah ga bisa masuk ad...  Negative
# 3     gimana ini aplikasi kok gak bisa di gunakan sa...  Negative
# 4     sebelumnya ada pilihan warga negara saya sudah...  Negative
# ...                                                 ...       ...
# 1943                               aku gak bis masuknya  Negative
# 1944                                   ko gx bisa login  Negative
# 1945                                 koq gak mau kebuka  Negative
# 1946                                 semoga sehat semua  Positive
# 1947                                    sangat membantu  Positive
#
#                                             text_tokens
# 0     [biasanya, saya, scan, qr, code, di, lobby, ka...
# 1     [setelah, diupdate, versi, terbaru, kok, malah...
# 2     [sekarang, update, terbaru, malah, ga, bisa, m...
# 3     [gimana, ini, aplikasi, kok, gak, bisa, di, gu...
# 4     [sebelumnya, ada, pilihan, warga, negara, saya...
# ...                                                 ...
# 1943                          [aku, gak, bis, masuknya]
# 1944                              [ko, gx, bisa, login]
# 1945                            [koq, gak, mau, kebuka]
# 1946                             [semoga, sehat, semua]
# 1947                                 [sangat, membantu]
#
# [1945 rows x 4 columns]

# %% [markdown]
# # Menghapus stopwords

# %%
list_stopwords = stopwords.words('indonesian')
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah'])

txt_stopword = pd.read_csv("stopwords.txt", names= ["stopwords"], header = None)
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))
list_stopwords = set(list_stopwords)
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]
df_skripsi['text_tokens_WSW'] = df_skripsi['text_tokens'].apply(stopwords_removal)

# %%
list_stopwords
# Out:
# {'',
#  'eng',
#  'selamanya',
#  'heeeeellloooo',
#  'n',
#  'laelah',
#  'bla',
#  'horeee',
#  'nguyu',
#  'kem',
#  'saya',
#  'vi',
#  'jengn',
#  'orang',
#  'hadeeuh',
#  'nyatanya',
#  'beh',
#  'pak',
#  'terbanyak',
#  'kapanpun',
#  'mengingat',
#  'nge',
#  'dirinya',
#  'tu',
#  'terjadi',
#  'mistakes',
#  'ketika',
#  'meyakini',
#  'memulai',
#  'diberikan',
#  'jleb',
#  'emng',
#  'abc',
#  'hmm',
#  'ditunjukkannya',
#  'seterusnya',
#  'sib',
#  'gak',
#  'bersiap',
#  'diketahuinya',
#  'smple',
#  'ahaaaaa',
#  'sebabnya',
#  'terb',
#  'dimaksud',
#  'yes',
#  'inilah',
#  'gitulah',
#  'can',
#  'lalu',
#  'thd',
#  'bahkan',
#  'ditandaskan',
#  'ka',
#  'ju',
#  'm',
#  'cam',
#  'belakang',
#  'duh',
#  'enggak',
#  'sampaikan',
#  'berturut',
#  'ucapnya',
#  'kes',
#  'sebelum',
#  'adoh',
#  'cour',
#  'aiiihhh',
#  'pret',
#  'yakali',
#  'da',
#  'hello',
#  'seberapa',
#  'waduhhh',
#  'astagfirullah',
#  'o',
#  'syyo',
#  'dini',
#  'beri',
#  'inginkah',
#  'aih',
#  'kerja',
#  'db',
#  'diingatkan',
#  'loe',
#  'mungkinkah',
#  'sela',
#  'masa',
#  'sesaat',
#  'diberikannya',
#  'ditambahkan',
#  'semaunya',
#  'mb',
#  'dimaksudnya',
#  'sebutnya',
#  'memperbuat',
#  'menyiapkan',
#  'om',
#  'euy',
#  'berkata',
#  'diungkapkan',
#  'adapun',
#  'jika',
#  'keseluruhan',
#  'setiba',
#  'tuju',
#  'makanya',
#  'selaku',
#  'sepantasnya',
#  'menegaskan',
#  'soalnya',
#  'or',
#  'tertuju',
#  'i',
#  'maupun',
#  'jee',
#  'ay',
#  'look',
#  'mg',
#  'seharusnya',
#  'bo',
#  'twit',
#  'zzz',
#  'tgjwb',
#  'bulan',
#  'apalagi',
#  'pd',
#  'kelima',
#  'nya',
#  'ehhhh',
#  'rj',
#  'ke',
#  'sampai',
#  'bukanya',
#  'coz',
#  'jelasnya',
#  'tepat',
#  'mulailah',
#  'merasa',
#  'he',
#  'gaess',
#  'sak',
#  'aaah',
#  'wuiiih',
#  'jiah',
#  'kalaulah',
#  'secara',
#  'koit',
#  'ld',
#  'er',
#  'siapakah',
#  'ela',
#  'hsil',
#  'tdak',
#  'kadar',
#  'waktu',
#  'fii',
#  'oiya',
#  'share',
#  'tempat',
#  'seh',
#  'aeeee',
#  'terlalu',
#  'dahhh',
#  'bertanya-tanya',
#  'dn',
#  'di',
#  'lima',
#  'supaya',
#  'ditanya',
#  'sebegitu',
#  'ibaratkan',
#  'karenanya',
#  'death',
#  'perlu',
#  'pasi',
#  'np',
#  'sekitarnya',
#  'buat',
#  'ja',
#  'x',
#  'setengah',
#  'panjang',
#  'ndroo',
#  'tw',
#  'dab',
#  'mengungkapkan',
#  'sendirian',
#  'seusai',
#  'dg',
#  'siep',
#  'naik',
#  'jelaskan',
#  'wah',
#  'ngo',
#  'jan',
#  'audzubillah',
#  'lohh',
#  'menanyai',
#  'itukah',
#  'inikah',
#  'khususnya',
#  'cc',
#  'yoiii',
#  'hadech',
#  'bgt',
#  'dpt',
#  'fyi',
#  'benarkah',
#  'amp',
#  'dua',
#  'siip',
#  'gn',
#  'diantaranya',
#  'man',
#  'akhirnya',
#  'mendapat',
#  'ampe',
#  'jangankan',
#  'th',
#  'bagainamakah',
#  'wihhhhh',
#  'toet',
#  'tadinya',
#  'cuy',
#  'doing',
#  'wkwkw',
#  'u',
#  'apaa',
#  'kala',
#  'ngak',
#  'peeeeetttt',
#  'drpd',
#  'berdatangan',
#  'bai',
#  'halo',
#  'sbuah',
#  'lha',
#  'please',
#  'demikian',
#  'jgn',
#  'hadap',
#  'ehe',
#  'r',
#  'kal',
#  'kn',
#  'helo',
#  'awokaowkaowk',
#  'trus',
#  'bersama-sama',
#  'sudahkah',
#  'ga',
#  'hilihhh',
#  'sj',
#  'akulah',
#  'pen',
#  'ajasi',
#  'bawah',
#  'uhmmm',
#  'asa',
#  'hey',
#  'ci',
#  'couldn',
#  'beberapa',
#  'sebagian',
#  'did',
#  'se',
#  'mengibaratkan',
#  'ngk',
#  'pihaknya',
#  'haha',
#  'bertutur',
#  'tdk',
#  'pohonnnn',
#  'ato',
#  'bisa',
#  'berapapun',
#  'memerlukan',
#  'rrrrrr',
#  'dipertanyakan',
#  'per',
#  'sesudah',
#  'kenapa',
#  'ind',
#  'pantas',
#  'men',
#  'bahahaha',
#  'belumlah',
#  'na',
#  'terhadap',
#  'blenggg',
#  'ajaah',
#  'ani',
#  'dijelaskan',
#  'ehh',
#  'mengakhiri',
#  'lahhh',
#  'mengetahui',
#  'kurang',
#  'memberi',
#  'ayyy',
#  'no',
#  'eiy',
#  'en',
#  'secukupnya',
#  'pasti',
#  'peesai',
#  'antaranya',
#  'yv',
#  'ntr',
#  'blo',
#  'it',
#  'sempat',
#  'tetapi',
#  'bakal',
#  'kira',
#  'tutur',
#  'ssst',
#  'mengatakannya',
#  'mengira',
#  'spt',
#  'semampunya',
#  'manakala',
#  'seluruh',
#  'seolah-olah',
#  'mgg',
#  'wooyy',
#  'jadinya',
#  'nuh',
#  'dijelaskannya',
#  'ok',
#  'imf',
#  'tunjuk',
#  'pek',
#  'akutuh',
#  'j',
#  'from',
#  'diberi',
#  'sesama',
#  'hmmmmm',
#  'kebetulan',
#  'ti',
#  'aplagi',
#  'cm',
#  'keinginan',
#  'woyy',
#  'dll',
#  'diperlukan',
#  'kagak',
#  'menandaskan',
#  'walaupun',
#  'hadeeeeehhh',
#  'baik',
#  'kecil',
#  'sud',
#  'semasa',
#  'my',
#  'sambil',
#  'rang',
#  'koe',
#  'gar',
#  'sebelumnya',
#  'tl',
#  'siapa',
#  'termasuk',
#  'sssst',
#  'jah',
#  'apain',
#  'jumlahnya',
#  'belakangan',
#  'tahu',
#  'yaa',
#  'kpd',
#  'noh',
#  'awalnya',
#  'ujar',
#  'pertanyakan',
#  'dikatakan',
#  'biarpun',
#  'siiiiiiiih',
#  'bermacam-macam',
#  'sebagai',
#  'disinilah',
#  'sekecil',
#  'tik',
#  'za',
#  'setidaknya',
#  'tambah',
#  'dahulu',
#  'toh',
#  'bikin',
#  'yupsss',
#  'lat',
#  'cokkk',
#  'sin',
#  'tandasnya',
#  'oi',
#  'siap',
#  'sesuatu',
#  'asyik',
#  'melakukan',
#  'apaaaannnn',
#  'namun',
#  'terdahulu',
#  'memungkinkan',
#  'follow',
#  'kasihh',
#  'lohhhh',
#  'olehnya',
#  'terjadilah',
#  'nii',
#  'tampak',
#  'seperti',
#  'tir',
#  'jin',
#  'meh',
#  'lbh',
#  'ntah',
#  'seenaknya',
#  'waaahh',
#  'guna',
#  'tahun',
#  'omg',
#  'neh',
#  'disebut',
#  'awal',
#  'bersama',
#  'aig',
#  'sedangkan',
#  'menghendaki',
#  'kelihatan',
#  'berjumlah',
#  'keri',
#  'nyaris',
#  'oei',
#  'bwa',
#  'segala',
#  'broo',
#  'satu',
#  'andalah',
#  'mengingatkan',
#  'iyaa',
#  'tiap',
#  'bahwasannya',
#  'semuanya',
#  'masuk',
#  'kepadanya',
#  'melalui',
#  'kah',
#  'assuuu',
#  'sebaik-baiknya',
#  'hallo',
#  'tsbt',
#  'may',
#  'kepa',
#  'saatnya',
#  'rb',
#  'mempersiapkan',
#  'moga',
#  'do',
#  'gk',
#  'disebutkannya',
#  'serupa',
#  'dimintai',
#  'dink',
#  'mirip',
#  'sebegini',
#  'untuk',
#  'atuh',
#  'dmn',
#  'woy',
#  'dipunyai',
#  'asn',
#  'tr',
#  'sekaligus',
#  'say',
#  'of',
#  'lagi',
#  'bisn',
#  'punya',
#  'al',
#  'ama',
#  'bkn',
#  'menunjuki',
#  'kinilah',
#  'oh',
#  'tegas',
#  'xi',
#  'dikerjakan',
#  'tegasnya',
#  'menanyakan',
#  'keseluruhannya',
#  'pula',
#  'menanya',
#  'malah',
#  'yakni',
#  'misalkan',
#  'bukan',
#  'diantara',
#  'sebagainya',
#  'dust',
#  'didatangkan',
#  'dp',
#  'beib',
#  'dng',
#  'ne',
#  'kemungkinannya',
#  'cuih',
#  'wonderfull',
#  'ajjaaa',
#  'spya',
#  'what',
#  'mere',
#  'melihat',
#  'berupa',
#  'yukk',
#  'sini',
#  'sekrg',
#  'aahh',
#  'waahh',
#  'ah',
#  'mengapa',
#  'z',
#  'bagiamana',
#  'ujarnya',
#  'macam',
#  'begitulah',
#  'ss',
#  'sebut',
#  'ms',
#  'mampu',
#  'common',
#  'eihh',
#  'asiiik',
#  'caranya',
#  'tuu',
#  'apaan',
#  'aang',
#  'woooooi',
#  'haiii',
#  'diibaratkan',
#  'nih',
#  'awokawokawok',
#  'ben',
#  'sig',
#  'tentu',
#  'jikalau',
#  'ahhahshahahsha',
#  'yo',
#  'tetap',
#  'jab',
#  'ji',
#  'bekerja',
#  'jangan',
#  'aj',
#  'aaa',
#  'met',
#  'ndase',
#  'bnyk',
#  'hendaklah',
#  'sekaranglah',
#  'sy',
#  'menanti',
#  'diperbuat',
#  'spy',
#  'enggaknya',
#  'thread',
#  'bgmn',
#  'seluruhnya',
#  'meng',
#  'hehe',
#  'haduh',
#  'jawaban',
#  'wyg',
#  'setibanya',
#  'teringat',
#  'asik',
#  'menambahkan',
#  'dari',
#  'menyampaikan',
#  'yth',
#  'aseekk',
#  'berturut-turut',
#  'cuk',
#  'diperbuatnya',
#  'anta',
#  'kam',
#  'antara',
#  'betulkah',
#  'ialah',
#  'suggest',
#  'maaaaad',
#  'semula',
#  'jat',
#  'digunakan',
#  'berujar',
#  'pernah',
#  'sekurangnya',
#  'wkwaww',
#  'sebab',
#  'ntuh',
#  'bilang',
#  'tp',
#  'semua',
#  'tuk',
#  'kak',
#  'ojo',
#  'ungkap',
#  'ajib',
#  'dimulainya',
#  'kor',
#  'piyu',
#  'klw',
#  'sering',
#  'bukannya',
#  'ng',
#  'bukanlah',
#  'seperlunya',
#  'yee',
#  'memperkirakan',
#  'mas',
#  'update',
#  'keleus',
#  'mo',
#  'sesudahnya',
#  'kalo',
#  'g',
#  'wen',
#  'menyangkut',
#  'beginilah',
#  'guys',
#  'apabedanya',
#  'hiikksss',
#  'bagaimanapun',
#  'penting',
#  'hk',
#  'peny',
#  'begitu',
#  'mba',
#  'woi',
#  'sendirinya',
#  'sh',
#  'dibuatnya',
#  'sesampai',
#  'kpn',
#  'agree',
#  'apakh',
#  'dituturkannya',
#  'utk',
#  'sdh',
#  'hny',
#  'fa',
#  'huhuhu',
#  'kua',
#  'sebenarnya',
#  'dimaksudkannya',
#  'lagian',
#  'sekali-kali',
#  'menjadi',
#  'tidak',
#  'mengenai',
#  'mau',
#  'suatu',
#  'tambahnya',
#  'world',
#  'ieu',
#  'bro',
#  'begitukah',
#  'dikarenakan',
#  'nie',
#  'donk',
#  'sangkut',
#  'ih',
#  'awwww',
#  'the',
#  'ckckck',
#  'ditanyakan',
#  'ca',
#  'yu',
#  'seseorang',
#  'nyang',
#  'arb',
#  'kepada',
#  'mi',
#  'disini',
#  'diinginkan',
#  'tau',
#  's',
#  'yuk',
#  'mempersoalkan',
#  'tak',
#  'pihak',
#  'bun',
#  'ndy',
#  'sibuj',
#  'preesss',
#  'backstreet',
#  'cukuplah',
#  'mempunyai',
#  'diperlihatkan',
#  'cai',
#  'that',
#  'woii',
#  'practice',
#  'msh',
#  'mam',
#  'gass',
#  'alhamdulillah',
#  'laahh',
#  'dtg',
#  'kemungkinan',
#  'yaitu',
#  'bapak',
#  'le',
#  'kembali',
#  'ooo',
#  'disampaikan',
#  'ia',
#  'mahl',
#  'menaiki',
#  'akankah',
#  'menyatakan',
#  'semakin',
#  'jdkn',
#  'bagi',
#  'teh',
#  'mengerjakan',
#  'bagemana',
#  'tersebut',
#  'wow',
#  'pis',
#  'tsb',
#  'ade',
#  'gpp',
#  'wong',
#  'sebaliknya',
#  'sich',
#  'ihh',
#  'fir',
#  'bukankah',
#  'sangat',
#  'gih',
#  'leb',
#  'ataupun',
#  'juaraaa',
#  'mengucapkannya',
#  'ealah',
#  'tour',
#  'bwt',
#  'setinggi',
#  'gug',
#  'meski',
#  'kr',
#  'janganlah',
#  'terasa',
#  'good',
#  'ingin',
#  'following',
#  'his',
#  'ser',
#  'blm',
#  'dlm',
#  'peke',
#  'apalgi',
#  'dila',
#  'ahhhhh',
#  'are',
#  'tentang',
#  'wk',
#  'lebih',
#  'ya',
#  'rupanya',
#  'balik',
#  'lihat',
#  'poi',
#  'seorang',
#  'atr',
#  'cik',
#  'xs',
#  'baiklah',
#  'ndezz',
#  '&amp',
#  'depan',
#  'saat',
#  'karena',
#  'yakin',
#  'ol',
#  'aahhh',
#  'ajaa',
#  'berlangsung',
#  'memba',
#  'tentunya',
#  'jagan',
#  'tuit',
#  'apabilah',
#  'kita',
#  'bi',
#  'gmn',
#  'ahool',
#  'for',
#  'pp',
#  'selama-lamanya',
#  'aduhh',
#  'yah',
#  'hsl',
#  'haahaaa',
#  'woooyyyyy',
#  'mlm',
#  'c',
#  'mul',
#  'kelihatannya',
#  'lum',
#  'aplg',
#  'jd',
#  'sesekali',
#  'nan',
#  'ditujukan',
#  'dan',
#  'diar',
#  'mm',
#  'and',
#  'siapapun',
#  'kantri',
#  'pre',
#  'juga',
#  'ditanyai',
#  'mem',
#  'they',
#  'tidakkah',
#  'eaaaa',
#  'meyakinkan',
#  'woyyy',
#  'lanjut',
#  'mai',
#  'dy',
#  'min',
#  'march',
#  'selalu',
#  'ping',
#  'pt',
#  'lamanya',
#  'f',
#  'wj',
#  'abd',
#  'pol',
#  'sangatlah',
#  'sek',
#  'is',
#  'sang',
#  'more',
#  'para',
#  'selanjutnya',
#  'masihkah',
#  'nder',
#  'tersebutlah',
#  'cukupkah',
#  'wa',
#  'menyeluruh',
#  'sih',
#  'menantikan',
#  'ntup',
#  'sayalah',
#  'berlebihan',
#  'a',
#  'wooiiii',
#  'dibia',
#  'ni',
#  'org',
#  'pentingnya',
#  'diucapkan',
#  'menanti-nanti',
#  'tri',
#  'hend',
#  'lo',
#  'salam',
#  'nyok',
#  'diibaratkannya',
#  'kerna',
#  'dapat',
#  'ngoahahahahahaaa',
#  'tela',
#  'btw',
#  'eo',
#  'kan',
#  'bilakah',
#  'eye',
#  'mendatang',
#  'kamilah',
#  'jauh',
#  'mulai',
#  'usah',
#  'daripada',
#  'don',
#  'ai',
#  'sajalah',
#  'ho',
#  'ditegaskan',
#  'umumnya',
#  'hayo',
#  'jomp',
#  'et',
#  'la',
#  'ibarat',
#  'gimana',
#  'diminta',
#  'semampu',
#  'akubingin',
#  'menggunakan',
#  'blom',
#  'ailapyupul',
#  'wahai',
#  'ntap',
#  'wooiii',
#  'eh',
#  'melihatnya',
#  'keluar',
#  'yan',
#  'ra',
#  'te',
#  'tanyanya',
#  'tur',
#  'alla',
#  'tep',
#  'tersampaikan',
#  'sem',
#  'heleh',
#  'eeeh',
#  'rt',
#  't',
#  'gom',
#  'lewat',
#  'by',
#  'lak',
#  'enak',
#  'atas',
#  'tiba',
#  'keunn',
#  'bas',
#  'aaaakkkhhhhhh',
#  'dech',
#  'bur',
#  'membuat',
#  'ken',
#  'pertanyaan',
#  'wouy',
#  'laku',
#  'dikira',
#  'entahlah',
#  'cuma',
#  'gsk',
#  'aja',
#  'uittt',
#  'su',
#  'at',
#  'again',
#  'rata',
#  'kitalah',
#  'tanpa',
#  'ma',
#  'kasus',
#  'beginian',
#  'dijawab',
#  'jumlah',
#  'so',
#  'merupakan',
#  'banyak',
#  'mendapatkan',
#  'adanya',
#  'hendak',
#  'ungkapnya',
#  'nahh',
#  'lho',
#  'mbh',
#  'gangs',
#  'bagaimana',
#  'dipergunakan',
#  'jawab',
#  'minta',
#  'sam',
#  'semata-mata',
#  'kwak',
#  'berada',
#  'nantinya',
#  'apa',
#  'udahlah',
#  'khusus',
#  'pi',
#  'dipersoalkan',
#  'disebutkan',
#  'kapan',
#  'sama-sama',
#  'pertama',
#  'itu',
#  'tadi',
#  'asseeekkkk',
#  'kesampaian',
#  'gitu',
#  'ooohhh',
#  'smuwa',
#  'menuturkan',
#  ...}

# %%
df_skripsi
# Out:
#                                               text_real  \
# 0     Biasanya saya scan QR code di lobby kantor set...
# 1     Setelah di-update versi terbaru kok malah gak ...
# 2     Sekarang Update terbaru malah ga bisa masuk ad...
# 3     Gimana ini aplikasi kok gak bisa di gunakan. S...
# 4     Sebelumnya ada pilihan warga negara, saya suda...
# ...                                                 ...
# 1943                               aku gak bis masuknya
# 1944                                  Ko gx bisa login.
# 1945                                 Koq gak mau kebuka
# 1946                                 Semoga sehat semua
# 1947                                sangat membantu,, 👍
#
#                                                    text     label  \
# 0     biasanya saya scan qr code di lobby kantor set...  Negative
# 1     setelah diupdate versi terbaru kok malah gak b...  Negative
# 2     sekarang update terbaru malah ga bisa masuk ad...  Negative
# 3     gimana ini aplikasi kok gak bisa di gunakan sa...  Negative
# 4     sebelumnya ada pilihan warga negara saya sudah...  Negative
# ...                                                 ...       ...
# 1943                               aku gak bis masuknya  Negative
# 1944                                   ko gx bisa login  Negative
# 1945                                 koq gak mau kebuka  Negative
# 1946                                 semoga sehat semua  Positive
# 1947                                    sangat membantu  Positive
#
#                                             text_tokens  \
# 0     [biasanya, saya, scan, qr, code, di, lobby, ka...
# 1     [setelah, diupdate, versi, terbaru, kok, malah...
# 2     [sekarang, update, terbaru, malah, ga, bisa, m...
# 3     [gimana, ini, aplikasi, kok, gak, bisa, di, gu...
# 4     [sebelumnya, ada, pilihan, warga, negara, saya...
# ...                                                 ...
# 1943                          [aku, gak, bis, masuknya]
# 1944                              [ko, gx, bisa, login]
# 1945                            [koq, gak, mau, kebuka]
# 1946                             [semoga, sehat, semua]
# 1947                                 [sangat, membantu]
#
#                                         text_tokens_WSW
# 0     [scan, qr, code, lobby, kantor, pagitetapi, ap...
# 1     [diupdate, versi, terbaru, dibuka, bolak, forc...
# 2     [terbaru, centangan, setuju, diam, respon, hp,...
# 3     [aplikasi, downlod, centa, setujutapi, maksudn...
# 4     [pilihan, warga, negara, klik, wni, centang, s...
# ...                                                 ...
# 1943                                    [bis, masuknya]
# 1944                                    [ko, gx, login]
# 1945                                      [koq, kebuka]
# 1946                                    [semoga, sehat]
# 1947                                         [membantu]
#
# [1945 rows x 5 columns]

# %% [markdown]
# # Distribusi frekuensi NLTK

# %%
def freqDist_wrapper(text):
    return FreqDist(text)

df_skripsi['text_tokens_fdist'] = df_skripsi['text_tokens'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(df_skripsi['text_tokens_fdist'].head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(qr, 2), (code, 2), (update, 2), (biasanya, 1...
# 1    [(gak, 4), (bisa, 4), (dibuka, 3), (bolak, 2),...
# 2    [(hp, 5), (untuk, 4), (ga, 2), (masuk, 2), (aj...
# 3    [(gak, 4), (bisa, 3), (saya, 3), (gimana, 2), ...
# 4    [(saya, 4), (untuk, 4), (tidak, 4), (ada, 3), ...
# Name: text_tokens_fdist, dtype: object

# %% [markdown]
# # Filtering (penghapusan stopwords) / normalisasi

# %%
from nltk.corpus import stopwords

# %%
list_stopwords = stopwords.words('indonesian')

# %%
list_stopwords
# Out:
# ['ada',
#  'adalah',
#  'adanya',
#  'adapun',
#  'agak',
#  'agaknya',
#  'agar',
#  'akan',
#  'akankah',
#  'akhir',
#  'akhiri',
#  'akhirnya',
#  'aku',
#  'akulah',
#  'amat',
#  'amatlah',
#  'anda',
#  'andalah',
#  'antar',
#  'antara',
#  'antaranya',
#  'apa',
#  'apaan',
#  'apabila',
#  'apakah',
#  'apalagi',
#  'apatah',
#  'artinya',
#  'asal',
#  'asalkan',
#  'atas',
#  'atau',
#  'ataukah',
#  'ataupun',
#  'awal',
#  'awalnya',
#  'bagai',
#  'bagaikan',
#  'bagaimana',
#  'bagaimanakah',
#  'bagaimanapun',
#  'bagi',
#  'bagian',
#  'bahkan',
#  'bahwa',
#  'bahwasanya',
#  'baik',
#  'bakal',
#  'bakalan',
#  'balik',
#  'banyak',
#  'bapak',
#  'baru',
#  'bawah',
#  'beberapa',
#  'begini',
#  'beginian',
#  'beginikah',
#  'beginilah',
#  'begitu',
#  'begitukah',
#  'begitulah',
#  'begitupun',
#  'bekerja',
#  'belakang',
#  'belakangan',
#  'belum',
#  'belumlah',
#  'benar',
#  'benarkah',
#  'benarlah',
#  'berada',
#  'berakhir',
#  'berakhirlah',
#  'berakhirnya',
#  'berapa',
#  'berapakah',
#  'berapalah',
#  'berapapun',
#  'berarti',
#  'berawal',
#  'berbagai',
#  'berdatangan',
#  'beri',
#  'berikan',
#  'berikut',
#  'berikutnya',
#  'berjumlah',
#  'berkali-kali',
#  'berkata',
#  'berkehendak',
#  'berkeinginan',
#  'berkenaan',
#  'berlainan',
#  'berlalu',
#  'berlangsung',
#  'berlebihan',
#  'bermacam',
#  'bermacam-macam',
#  'bermaksud',
#  'bermula',
#  'bersama',
#  'bersama-sama',
#  'bersiap',
#  'bersiap-siap',
#  'bertanya',
#  'bertanya-tanya',
#  'berturut',
#  'berturut-turut',
#  'bertutur',
#  'berujar',
#  'berupa',
#  'besar',
#  'betul',
#  'betulkah',
#  'biasa',
#  'biasanya',
#  'bila',
#  'bilakah',
#  'bisa',
#  'bisakah',
#  'boleh',
#  'bolehkah',
#  'bolehlah',
#  'buat',
#  'bukan',
#  'bukankah',
#  'bukanlah',
#  'bukannya',
#  'bulan',
#  'bung',
#  'cara',
#  'caranya',
#  'cukup',
#  'cukupkah',
#  'cukuplah',
#  'cuma',
#  'dahulu',
#  'dalam',
#  'dan',
#  'dapat',
#  'dari',
#  'daripada',
#  'datang',
#  'dekat',
#  'demi',
#  'demikian',
#  'demikianlah',
#  'dengan',
#  'depan',
#  'di',
#  'dia',
#  'diakhiri',
#  'diakhirinya',
#  'dialah',
#  'diantara',
#  'diantaranya',
#  'diberi',
#  'diberikan',
#  'diberikannya',
#  'dibuat',
#  'dibuatnya',
#  'didapat',
#  'didatangkan',
#  'digunakan',
#  'diibaratkan',
#  'diibaratkannya',
#  'diingat',
#  'diingatkan',
#  'diinginkan',
#  'dijawab',
#  'dijelaskan',
#  'dijelaskannya',
#  'dikarenakan',
#  'dikatakan',
#  'dikatakannya',
#  'dikerjakan',
#  'diketahui',
#  'diketahuinya',
#  'dikira',
#  'dilakukan',
#  'dilalui',
#  'dilihat',
#  'dimaksud',
#  'dimaksudkan',
#  'dimaksudkannya',
#  'dimaksudnya',
#  'diminta',
#  'dimintai',
#  'dimisalkan',
#  'dimulai',
#  'dimulailah',
#  'dimulainya',
#  'dimungkinkan',
#  'dini',
#  'dipastikan',
#  'diperbuat',
#  'diperbuatnya',
#  'dipergunakan',
#  'diperkirakan',
#  'diperlihatkan',
#  'diperlukan',
#  'diperlukannya',
#  'dipersoalkan',
#  'dipertanyakan',
#  'dipunyai',
#  'diri',
#  'dirinya',
#  'disampaikan',
#  'disebut',
#  'disebutkan',
#  'disebutkannya',
#  'disini',
#  'disinilah',
#  'ditambahkan',
#  'ditandaskan',
#  'ditanya',
#  'ditanyai',
#  'ditanyakan',
#  'ditegaskan',
#  'ditujukan',
#  'ditunjuk',
#  'ditunjuki',
#  'ditunjukkan',
#  'ditunjukkannya',
#  'ditunjuknya',
#  'dituturkan',
#  'dituturkannya',
#  'diucapkan',
#  'diucapkannya',
#  'diungkapkan',
#  'dong',
#  'dua',
#  'dulu',
#  'empat',
#  'enggak',
#  'enggaknya',
#  'entah',
#  'entahlah',
#  'guna',
#  'gunakan',
#  'hal',
#  'hampir',
#  'hanya',
#  'hanyalah',
#  'hari',
#  'harus',
#  'haruslah',
#  'harusnya',
#  'hendak',
#  'hendaklah',
#  'hendaknya',
#  'hingga',
#  'ia',
#  'ialah',
#  'ibarat',
#  'ibaratkan',
#  'ibaratnya',
#  'ibu',
#  'ikut',
#  'ingat',
#  'ingat-ingat',
#  'ingin',
#  'inginkah',
#  'inginkan',
#  'ini',
#  'inikah',
#  'inilah',
#  'itu',
#  'itukah',
#  'itulah',
#  'jadi',
#  'jadilah',
#  'jadinya',
#  'jangan',
#  'jangankan',
#  'janganlah',
#  'jauh',
#  'jawab',
#  'jawaban',
#  'jawabnya',
#  'jelas',
#  'jelaskan',
#  'jelaslah',
#  'jelasnya',
#  'jika',
#  'jikalau',
#  'juga',
#  'jumlah',
#  'jumlahnya',
#  'justru',
#  'kala',
#  'kalau',
#  'kalaulah',
#  'kalaupun',
#  'kalian',
#  'kami',
#  'kamilah',
#  'kamu',
#  'kamulah',
#  'kan',
#  'kapan',
#  'kapankah',
#  'kapanpun',
#  'karena',
#  'karenanya',
#  'kasus',
#  'kata',
#  'katakan',
#  'katakanlah',
#  'katanya',
#  'ke',
#  'keadaan',
#  'kebetulan',
#  'kecil',
#  'kedua',
#  'keduanya',
#  'keinginan',
#  'kelamaan',
#  'kelihatan',
#  'kelihatannya',
#  'kelima',
#  'keluar',
#  'kembali',
#  'kemudian',
#  'kemungkinan',
#  'kemungkinannya',
#  'kenapa',
#  'kepada',
#  'kepadanya',
#  'kesampaian',
#  'keseluruhan',
#  'keseluruhannya',
#  'keterlaluan',
#  'ketika',
#  'khususnya',
#  'kini',
#  'kinilah',
#  'kira',
#  'kira-kira',
#  'kiranya',
#  'kita',
#  'kitalah',
#  'kok',
#  'kurang',
#  'lagi',
#  'lagian',
#  'lah',
#  'lain',
#  'lainnya',
#  'lalu',
#  'lama',
#  'lamanya',
#  'lanjut',
#  'lanjutnya',
#  'lebih',
#  'lewat',
#  'lima',
#  'luar',
#  'macam',
#  'maka',
#  'makanya',
#  'makin',
#  'malah',
#  'malahan',
#  'mampu',
#  'mampukah',
#  'mana',
#  'manakala',
#  'manalagi',
#  'masa',
#  'masalah',
#  'masalahnya',
#  'masih',
#  'masihkah',
#  'masing',
#  'masing-masing',
#  'mau',
#  'maupun',
#  'melainkan',
#  'melakukan',
#  'melalui',
#  'melihat',
#  'melihatnya',
#  'memang',
#  'memastikan',
#  'memberi',
#  'memberikan',
#  'membuat',
#  'memerlukan',
#  'memihak',
#  'meminta',
#  'memintakan',
#  'memisalkan',
#  'memperbuat',
#  'mempergunakan',
#  'memperkirakan',
#  'memperlihatkan',
#  'mempersiapkan',
#  'mempersoalkan',
#  'mempertanyakan',
#  'mempunyai',
#  'memulai',
#  'memungkinkan',
#  'menaiki',
#  'menambahkan',
#  'menandaskan',
#  'menanti',
#  'menanti-nanti',
#  'menantikan',
#  'menanya',
#  'menanyai',
#  'menanyakan',
#  'mendapat',
#  'mendapatkan',
#  'mendatang',
#  'mendatangi',
#  'mendatangkan',
#  'menegaskan',
#  'mengakhiri',
#  'mengapa',
#  'mengatakan',
#  'mengatakannya',
#  'mengenai',
#  'mengerjakan',
#  'mengetahui',
#  'menggunakan',
#  'menghendaki',
#  'mengibaratkan',
#  'mengibaratkannya',
#  'mengingat',
#  'mengingatkan',
#  'menginginkan',
#  'mengira',
#  'mengucapkan',
#  'mengucapkannya',
#  'mengungkapkan',
#  'menjadi',
#  'menjawab',
#  'menjelaskan',
#  'menuju',
#  'menunjuk',
#  'menunjuki',
#  'menunjukkan',
#  'menunjuknya',
#  'menurut',
#  'menuturkan',
#  'menyampaikan',
#  'menyangkut',
#  'menyatakan',
#  'menyebutkan',
#  'menyeluruh',
#  'menyiapkan',
#  'merasa',
#  'mereka',
#  'merekalah',
#  'merupakan',
#  'meski',
#  'meskipun',
#  'meyakini',
#  'meyakinkan',
#  'minta',
#  'mirip',
#  'misal',
#  'misalkan',
#  'misalnya',
#  'mula',
#  'mulai',
#  'mulailah',
#  'mulanya',
#  'mungkin',
#  'mungkinkah',
#  'nah',
#  'naik',
#  'namun',
#  'nanti',
#  'nantinya',
#  'nyaris',
#  'nyatanya',
#  'oleh',
#  'olehnya',
#  'pada',
#  'padahal',
#  'padanya',
#  'pak',
#  'paling',
#  'panjang',
#  'pantas',
#  'para',
#  'pasti',
#  'pastilah',
#  'penting',
#  'pentingnya',
#  'per',
#  'percuma',
#  'perlu',
#  'perlukah',
#  'perlunya',
#  'pernah',
#  'persoalan',
#  'pertama',
#  'pertama-tama',
#  'pertanyaan',
#  'pertanyakan',
#  'pihak',
#  'pihaknya',
#  'pukul',
#  'pula',
#  'pun',
#  'punya',
#  'rasa',
#  'rasanya',
#  'rata',
#  'rupanya',
#  'saat',
#  'saatnya',
#  'saja',
#  'sajalah',
#  'saling',
#  'sama',
#  'sama-sama',
#  'sambil',
#  'sampai',
#  'sampai-sampai',
#  'sampaikan',
#  'sana',
#  'sangat',
#  'sangatlah',
#  'satu',
#  'saya',
#  'sayalah',
#  'se',
#  'sebab',
#  'sebabnya',
#  'sebagai',
#  'sebagaimana',
#  'sebagainya',
#  'sebagian',
#  'sebaik',
#  'sebaik-baiknya',
#  'sebaiknya',
#  'sebaliknya',
#  'sebanyak',
#  'sebegini',
#  'sebegitu',
#  'sebelum',
#  'sebelumnya',
#  'sebenarnya',
#  'seberapa',
#  'sebesar',
#  'sebetulnya',
#  'sebisanya',
#  'sebuah',
#  'sebut',
#  'sebutlah',
#  'sebutnya',
#  'secara',
#  'secukupnya',
#  'sedang',
#  'sedangkan',
#  'sedemikian',
#  'sedikit',
#  'sedikitnya',
#  'seenaknya',
#  'segala',
#  'segalanya',
#  'segera',
#  'seharusnya',
#  'sehingga',
#  'seingat',
#  'sejak',
#  'sejauh',
#  'sejenak',
#  'sejumlah',
#  'sekadar',
#  'sekadarnya',
#  'sekali',
#  'sekali-kali',
#  'sekalian',
#  'sekaligus',
#  'sekalipun',
#  'sekarang',
#  'sekarang',
#  'sekecil',
#  'seketika',
#  'sekiranya',
#  'sekitar',
#  'sekitarnya',
#  'sekurang-kurangnya',
#  'sekurangnya',
#  'sela',
#  'selain',
#  'selaku',
#  'selalu',
#  'selama',
#  'selama-lamanya',
#  'selamanya',
#  'selanjutnya',
#  'seluruh',
#  'seluruhnya',
#  'semacam',
#  'semakin',
#  'semampu',
#  'semampunya',
#  'semasa',
#  'semasih',
#  'semata',
#  'semata-mata',
#  'semaunya',
#  'sementara',
#  'semisal',
#  'semisalnya',
#  'sempat',
#  'semua',
#  'semuanya',
#  'semula',
#  'sendiri',
#  'sendirian',
#  'sendirinya',
#  'seolah',
#  'seolah-olah',
#  'seorang',
#  'sepanjang',
#  'sepantasnya',
#  'sepantasnyalah',
#  'seperlunya',
#  'seperti',
#  'sepertinya',
#  'sepihak',
#  'sering',
#  'seringnya',
#  'serta',
#  'serupa',
#  'sesaat',
#  'sesama',
#  'sesampai',
#  'sesegera',
#  'sesekali',
#  'seseorang',
#  'sesuatu',
#  'sesuatunya',
#  'sesudah',
#  'sesudahnya',
#  'setelah',
#  'setempat',
#  'setengah',
#  'seterusnya',
#  'setiap',
#  'setiba',
#  'setibanya',
#  'setidak-tidaknya',
#  'setidaknya',
#  'setinggi',
#  'seusai',
#  'sewaktu',
#  'siap',
#  'siapa',
#  'siapakah',
#  'siapapun',
#  'sini',
#  'sinilah',
#  'soal',
#  'soalnya',
#  'suatu',
#  'sudah',
#  'sudahkah',
#  'sudahlah',
#  'supaya',
#  'tadi',
#  'tadinya',
#  'tahu',
#  'tahun',
#  'tak',
#  'tambah',
#  'tambahnya',
#  'tampak',
#  'tampaknya',
#  'tandas',
#  'tandasnya',
#  'tanpa',
#  'tanya',
#  'tanyakan',
#  'tanyanya',
#  'tapi',
#  'tegas',
#  'tegasnya',
#  'telah',
#  'tempat',
#  'tengah',
#  'tentang',
#  'tentu',
#  'tentulah',
#  'tentunya',
#  'tepat',
#  'terakhir',
#  'terasa',
#  'terbanyak',
#  'terdahulu',
#  'terdapat',
#  'terdiri',
#  'terhadap',
#  'terhadapnya',
#  'teringat',
#  'teringat-ingat',
#  'terjadi',
#  'terjadilah',
#  'terjadinya',
#  'terkira',
#  'terlalu',
#  'terlebih',
#  'terlihat',
#  'termasuk',
#  'ternyata',
#  'tersampaikan',
#  'tersebut',
#  'tersebutlah',
#  'tertentu',
#  'tertuju',
#  'terus',
#  'terutama',
#  'tetap',
#  'tetapi',
#  'tiap',
#  'tiba',
#  'tiba-tiba',
#  'tidak',
#  'tidakkah',
#  'tidaklah',
#  'tiga',
#  'tinggi',
#  'toh',
#  'tunjuk',
#  'turut',
#  'tutur',
#  'tuturnya',
#  'ucap',
#  'ucapnya',
#  'ujar',
#  'ujarnya',
#  'umum',
#  'umumnya',
#  'ungkap',
#  'ungkapnya',
#  'untuk',
#  'usah',
#  'usai',
#  'waduh',
#  'wah',
#  'wahai',
#  'waktu',
#  'waktunya',
#  'walau',
#  'walaupun',
#  'wong',
#  'yaitu',
#  'yakin',
#  'yakni',
#  'yang']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

clf =  RandomForestClassifier(random_state=0, max_features ='sqrt',max_depth = 100)
knn = KNeighborsClassifier(n_neighbors=7)
nb = GaussianNB()
dt = DecisionTreeClassifier(max_features ='sqrt',max_depth = 100)
svm = SVC(degree=3)
# clf.fit(X, y)

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

normalizad_word = pd.read_csv("colloquial-indonesian-lexicon (1).csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

df_skripsi['text_normalized'] = df_skripsi['text_tokens_WSW'].apply(normalized_term)


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df_skripsi['text_normalized']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df_skripsi['text_tokens_stemmed'] = df_skripsi['text_normalized'].swifter.apply(get_stemmed_term)
# Out:
# 4452
# ------------------------
# scan : scan
# qr : qr
# code : code
# lobby : lobby
# kantor : kantor
# pagitetapi : pagitetapi
# aplikasi : aplikasi
# errorscan : errorscan
# melebihi : lebih
# radius : radius
# error : error
# diupdate : diupdate
# versi : versi
# terbaru : baru
# dibuka : buka
# bolak : bolak
# force : force
# close : close
# sayangnya : sayang
# pedulilindungi : pedulilindungi
# berhenti : henti
# coba : coba
# uninstal : uninstal
# instal : instal
# hasilnya : hasil
# akun : akun
# vaksin : vaksin
# 1 : 1
# 2 : 2
# begini : begini
# nyusahkan : nyusahkan
# masyarakat : masyarakat
# repot : repot
# aplikasinya : aplikasi
# perbaiki : baik
# masak : masak
# beli : beli
# hape : hape
# gara : gara
# centangan : centangan
# setuju : tuju
# diam : diam
# respon : respon
# hp : hp
# teman : teman
# diperbaiki : baik
# dipakai : pakai
# seindonesia : indonesia
# ganti : ganti
# makan : makan
# susah : susah
# rakyat : rakyat
# urgent : urgent
# android : android
# dibawah : bawah
# 6 : 6
# support : support
# pakai : pakai
# 5 : 5
# berat : berat
# pemerintah : perintah
# sumbang : sumbang
# downlod : downlod
# centa : centa
# setujutapi : setujutapi
# maksudnya : maksud
# kemarin : kemarin
# pergi2 : pergi2
# check : check
# barcode : barcode
# maunya : mau
# peduli : peduli
# lindung : lindung
# pilihan : pilih
# warga : warga
# negara : negara
# klik : klik
# wni : wni
# centang : centang
# syarat : syarat
# penggunaan : guna
# kebijakan : bijak
# privasi : privasi
# selanjutnnya : selanjutnnya
# apapun : apa
# mengulangi : ulang
# hasil : hasil
# uninstall : uninstall
# solusinya : solusi
# mengunjungi : unjung
# mengharuskan : harus
# login : login
# semejak : semejak
# diwajibkan : wajib
# busway : busway
# terbuang : buang
# sampah : sampah
# memperlambat : lambat
# menghambat : hambat
# menyusahkan : susah
# merepotkan : repot
# menyebalkan : sebal
# benarbenar : benarbenar
# mempersulit : sulit
# sertifikat : sertifikat
# muncul : muncul
# gembel : gembel
# buka : buka
# pas : pas
# pilih : pilih
# kenegaraan : negara
# ikuti : ikut
# langkah : langkah
# ceklis : ceklis
# tombol : tombol
# geser : geser
# suport : suport
# penjelasannya : jelas
# mengalami : alami
# kenadala : kenadala
# log : log
# layar : layar
# tujuan : tuju
# memudahkan : mudah
# pekerjaan : kerja
# serius : serius
# tolong : tolong
# perhatikan : perhati
# sudut : sudut
# pandang : pandang
# konsumen : konsumen
# meninggalkannya : tinggal
# maksud : maksud
# gagal : gagal
# penyampaian : sampai
# buruk : buruk
# terima : terima
# kasih : kasih
# download : download
# baikbaik : baikbaik
# kesalahan : salah
# terhapus : hapus
# lindungi : lindung
# kok : kok
# scroll : scroll
# diulang : ulang
# keadaannya : ada
# enggak : enggak
# mempermudah : mudah
# errornya : errornya
# banding : banding
# berhasilnya : hasil
# location : location
# aktif : aktif
# sesuai : sesuai
# titik : titik
# sudah : sudah
# dari : dari
# becanda : becanda
# sebel : sebel
# pagi : pagi
# dibikin : bikin
# setres : tres
# gegara : gegara
# masuk : masuk
# gedung : gedung
# terhambat : hambat
# karena : karena
# mulu : mulu
# infokan : info
# otomatis : otomatis
# wifi : wifi
# sertitikat : sertitikat
# apkikasi : apkikasi
# email : email
# format : format
# permohonan : mohon
# sertivikat : sertivikat
# infonya : info
# proses : proses
# silakan : sila
# menghubungi : hubung
# penyelenggara : selenggara
# menubggu : menubggu
# hubungi : hubung
# wewenangnya : wewenangnya
# daa : daa
# install : install
# membutuhkan : butuh
# membuka : buka
# ribet : ribet
# evisien : evisien
# mending : mending
# penumpang : tumpang
# memesan : mes
# tiket : tiket
# kereta : kereta
# transportasi : transportasi
# pcrantigen : pcrantigen
# belumotamatis : belumotamatis
# data : data
# dsb : dsb
# pembelian : beli
# cepat : cepat
# bobrok : bobrok
# memalukan : malu
# app : app
# sekelas : kelas
# kementerian : menteri
# terkait : kait
# komplain : komplain
# memasukkan : masuk
# tanggal : tanggal
# lahir : lahir
# kebuka : buka
# wacana : wacana
# dompet : dompet
# digital : digital
# haallo : haallo
# sehat : sehat
# nieh : nieh
# parah : parah
# bagus : bagus
# jelek : jelek
# semenjak : semenjak
# paksa : paksa
# out : out
# kove : kove
# verifikasi : verifikasi
# otp : otp
# banget : banget
# via : via
# tetap : tetap
# lemot : lot
# sesi : sesi
# menunggu : tunggu
# 3 : 3
# jam : jam
# sumpah : sumpah
# kesel : kesel
# upgrade : upgrade
# tunggu : tunggu
# nomor : nomor
# verifikasinya : verifikasi
# sekalinya : sekali
# langsunh : langsunh
# menunya : menu
# disuruh : suruh
# dibantu : bantu
# kecewa : kecewa
# tekan : tekan
# kebawah : bawah
# keluar : keluar
# layarnya : layar
# initolong : initolong
# kemana : mana
# lihat : lihat
# reset : reset
# playstore : playstore
# intinya : inti
# diceklis : diceklis
# notifikasi : notifikasi
# apa-apa : apa
# kesulitan : sulit
# publik : publik
# place : place
# fasilitas : fasilitas
# apl : apl
# pedulindungi : pedulindungi
# ver6 : ver6
# mengakses : akses
# apk : apk
# ver7 : ver7
# keatas : atas
# kesenjangan : senjang
# sosial : sosial
# ditindak : tindak
# aktifitas : aktifitas
# perhatiannya : perhati
# nik : nik
# begitu : begitu
# kakek2 : kakek2
# nenek-nenek : nenek
# akses : akses
# bantu : bantu
# kakek : kakek
# nenek : nenek
# keluarga : keluarga
# mu : mu
# kayak : kayak
# dihidupin : dihidupin
# 10 : 10
# anggota : anggota
# gajinya : gaji
# gede : gede
# bijaklah : bijak
# thanks : thanks
# puskesmas : puskesmas
# jadwal : jadwal
# suami : suami
# terdaftar : daftar
# keterangannya : terang
# dilogout : dilogout
# berkali : kali
# input : input
# semoga : moga
# krusial : krusial
# bepergian : pergi
# telepon : telepon
# kode : kode
# terkirim : kirim
# niat : niat
# mengasih : asih
# bintang : bintang
# play : play
# store : store
# padahal : padahal
# sistemnya : sistem
# tulisan : tulis
# discroll : discroll
# baca : baca
# balasan : balas
# ulasan : ulas
# suruh : suruh
# 70 : 70
# ver : ver
# assalamualaikum : assalamualaikum
# selamat : selamat
# berjalan : jalan
# daftar : daftar
# profesional : profesional
# mencangkup : cangkup
# jutaan : juta
# membuag : membuag
# kesal : kesal
# kendala : kendala
# selogan : log
# menyelamatkan : selamat
# asalan : asal
# benar : benar
# faksin : faksin
# mencoba : coba
# nama : nama
# hadehh : hadehh
# secepatnya : cepat
# merugikan : rugi
# scrolling : scrolling
# invalid : invalid
# token : token
# sistem : sistem
# berulang2 : berulang2
# 5x : 5x
# bugnya : bugnya
# kegiatan : giat
# gila : gila
# berlaku : laku
# menit : menit
# tlglah : tlglah
# dibthkan : dibthkan
# enggak jelas : enggak jelas
# sendirilah : sendiri
# dikasih : kasih
# senang : senang
# sehari : hari
# auto : auto
# checkout : checkout
# ingat : ingat
# karyawan : karyawan
# staff : staff
# cukupdapat : cukupdapat
# membantu : bantu
# loker : loker
# cari : cari
# admin : admin
# tidur : tidur
# mengeluh : keluh
# stuck : stuck
# halaman : halaman
# dijadikan : jadi
# ketentuan : tentu
# dibenahi : benah
# saran : saran
# berenti : renti
# persetujuan : tuju
# font : font
# terkecil : kecil
# pengaturan : atur
# ukuran : ukur
# benaran : benar
# komen : komen
# cobaalhamdulillah : cobaalhamdulillah
# kesini : kesini
# gue : gue
# jelas-jelas : jelas
# divaksindi : divaksindi
# terpampang : pampang
# sertifikatnyatp : sertifikatnyatp
# status : status
# merahblm : merahblm
# divaksinsudah : divaksinsudah
# kirim : kirim
# emailini : emailini
# itupretsekarang : itupretsekarang
# harus : harus
# terbaruaduh : terbaruaduh
# ajaini : ajaini
# buatnya : buat
# koplakmasa : koplakmasa
# kalah : kalah
# shoppeelazadatokopedia : shoppeelazadatokopedia
# sungguh : sungguh
# tiba-tiba : tiba
# crash : crash
# logout : logout
# disayangkan : sayang
# mengecewakan : kecewa
# mobilitas : mobilitas
# sdangkan : sdangkan
# dibutuhin : dibutuhin
# sekarang : sekarang
# dimana2 : dimana2
# keluhan : keluh
# ku : ku
# mayoritas : mayoritas
# bug : bug
# henfon : henfon
# gasemua : gasemua
# henfonnya : henfonnya
# untung : untung
# ditambah : tambah
# dilihat : lihat
# memadai : pada
# izin : izin
# lokasinya : lokasi
# annoying : annoying
# maksa : maksa
# dilock : dilock
# appnya : appnya
# background : background
# konsumsi : konsumsi
# baterai : baterai
# boros : boros
# tambahan : tambah
# fail : fail
# 1menit : 1menit
# 3jam : 3jam
# habis : habis
# beres : beres
# benerin : benerin
# hapus : hapus
# aturan : atur
# pemakaian : pakai
# program : program
# disempurnakan : sempurna
# tampilan : tampil
# dinamis : dinamis
# mengikuti : ikut
# pendek : pendek
# menampilkan : tampil
# mengerti : erti
# mencentang : centang
# persyaratan : syarat
# sukses : sukses
# layaknya : layak
# pengiriman : kirim
# unistall : unistall
# diklik : klik
# indonesia : indonesia
# keberbagai : bagai
# perjalanan : jalan
# tau-tau : tau
# privasitpi : privasitpi
# list : list
# kelanjutannya : lanjut
# mengapai : kapai
# aktivitas : aktivitas
# inimakin : inimakin
# maaf : maaf
# unduh : unduh
# asing : asing
# lanjutannya : lanjut
# bantuannyaterima : bantuannyaterima
# uinya : uinya
# diubah : ubah
# berantakan : beranta
# perbaikan : baik
# sisi : sisi
# backendnya : backendnya
# checkin : checkin
# dibilang : bilang
# tautan : taut
# apps : apps
# sampai : sampai
# memilih : pilih
# wnicontreng : wnicontreng
# sebenarnya : benar
# submit : submit
# setting : setting
# hptampilanukuran : hptampilanukuran
# tekspilih : tekspilih
# alami : alami
# pembuat : buat
# terimakasih : terimakasih
# menginstal : menginstal
# tanda : tanda
# menerima : terima
# isi : isi
# kursor : kursor
# melanjutkan : lanjut
# kotak : kotak
# biru : biru
# 8 : 8
# mhn : mhn
# bantuan : bantu
# informasinya : informasi
# tanggung : tanggung
# jawab : jawab
# kenapa : kenapa
# lagi : lagi
# hanya : hanya
# kemkes : kemkes
# ri : ri
# menyepelakan : pelak
# fix : fix
# berguna : guna
# emosi : emosi
# buatan : buat
# corporate : corporate
# swasta : swasta
# user : user
# friendly : friendly
# kakak : kakak
# setujui : tuju
# dadakan : dada
# corona : corona
# kodenya : kode
# failed : failed
# hemm : hemm
# pusing : pusing
# kepentingan : penting
# 13102021 : 13102021
# test : test
# swab : swab
# pcr : pcr
# negatif : negatif
# covid : covid
# 402 : 402
# riwayat : riwayat
# kesehatan : sehat
# ngawur : ngawur
# desa : desa
# dinyatakan : nyata
# beresiko : resiko
# terkonfirmasi : konfirmasi
# developer : developer
# terbaik : baik
# redownload : redownload
# dicentang : centang
# persetujuannya : tuju
# discrool : discrool
# oke : oke
# semua : semua
# fitur : fitur
# diakses : akses
# pengecekan : kece
# surat : surat
# vaksinasi : vaksinasi
# terhenti : henti
# sebatas : batas
# gencar : gencar
# menyuruh : suruh
# mendukung : dukung
# anak : anak
# itnya : itnya
# msi : msi
# menjalankan : jalan
# diganti : ganti
# pekerja : kerja
# teknisinya : teknisi
# payah : payah
# kewarganegaraan : kewarganegaraan
# bisa2 : bisa2
# registrasi : registrasi
# kalau : kalau
# tempat-tempat : tempat
# cekin : cekin
# cekout : cekout
# plnya : plnya
# perangkat : perangkat
# xiaomi : xiaomi
# redmi : redmi
# note : note
# team : team
# gaji : gaji
# buta : buta
# memiliki : milik
# handphone : handphone
# sekolah : sekolah
# sosiologi : sosiologi
# telpon : telpon
# setelah : telah
# verify : verify
# salah : salah
# 20 : 20
# urusan : urus
# lapor : lapor
# sdm : sdm
# temui : temu
# dibanggakan : bangga
# kentang : kentang
# berhp : berhp
# memang : memang
# its : its
# okay : okay
# gapapa : gapapa
# lamalama : lamalama
# mati : mati
# virus : virus
# dalih : dalih
# memperbarui : baru
# hpnya : hpnya
# baru : baru
# butuhkan : butuh
# deptstore : deptstore
# sekedar : dar
# bukti : bukti
# vaksinkedua : vaksinkedua
# info : info
# ketiga : tiga
# diperbarui : baru
# jujur : jujur
# sebelumnyatrmksh : sebelumnyatrmksh
# tanya : tanya
# barusan : barusan
# mucul : mucul
# pencetan : pencet
# apknya : apknya
# barang : barang
# eror : eror
# dimohon : mohon
# bantuannya : bantu
# bagaimana : bagaimana
# pelayananannya : pelayananannya
# giliran : gilir
# mentok : mentok
# mengurusi : urus
# masarakat : masarakat
# semudah : mudah
# kecuali : kecuali
# memangnya : memang
# pikir : pikir
# sarat : sarat
# penuhi : penuh
# kemudahan : mudah
# pengguna : guna
# kuliah : kuliah
# butuh : butuh
# doang : doang
# membedakan : beda
# uang : uang
# terimkasii : terimkasii
# kembalikan : kembali
# memersulit : sulit
# perusahaan : usaha
# absen : absen
# membingungkan : bingung
# keterangan : terang
# dimana : mana
# setelahnya : telah
# posisi : posisi
# dicek : cek
# enggak ada : enggak ada
# enggak bisa : enggak bisa
# call : call
# center : center
# dihubungi : hubung
# buatlah : buat
# parahnya : parah
# warna : warna
# hitam : hitam
# antigen : antigen
# berkali2 : berkali2
# paday : paday
# linkkan : linkkan
# saya : saya
# manfaat : manfaat
# terobosan : terobos
# solusi : solusi
# fikirkan : fikirkan
# kesusahan : susah
# menghadapi : hadap
# pandemi : pandemi
# memikirkan : pikir
# bangsa : bangsa
# negeri : negeri
# tercinta : cinta
# kewarganegaran : kewarganegaran
# bawahnya : bawah
# canggih : canggih
# mensupport : mensupport
# komplit : komplit
# kominfo : kominfo
# memberitahu : memberitahu
# diperbaharui : baharu
# diintruksikan : diintruksikan
# ulang : ulang
# 3x : 3x
# berhasil : hasil
# diperjelas : jelas
# perintah : perintah
# intruksi : intruksi
# tadi : tadi
# bisatolong : bisatolong
# stack : stack
# dihalaman : halaman
# menyetujui : tuju
# laman : laman
# os : os
# cacat : cacat
# lansia : lansia
# kasihan : kasihan
# 7 : 7
# update2 : update2
# dimodalin : dimodalin
# devolopernya : devolopernya
# permasalah : masa
# sertifkatnya : sertifkatnya
# dowload : dowload
# buang : buang
# paket : paket
# ampass : ampass
# vasin : vasin
# megajukan : megajukan
# tolonglah : tolong
# developernya : developer
# dibayar : bayar
# apbn : apbn
# beginian : begini
# becus : becus
# lu : lu
# dipersiapkan : siap
# mangap : mangap
# cerita : cerita
# dikit : dikit
# bp : bp
# pulang : pulang
# beliau : beliau
# dicoba : coba
# dihp : dihp
# apaw : apaw
# aneh : aneh
# keluaran : keluar
# memakai : pakai
# ke2tgl21102021 : ke2tgl21102021
# bareng : bareng
# tementapi : tementapi
# ke2 : ke2
# tersediasedangkan : tersediasedangkan
# tersedia : sedia
# besok : besok
# harinyadan : harinyadan
# sekarangmohon : sekarangmohon
# penjelasannyaterima : penjelasannyaterima
# sekira : sekira
# sesimpel : simpel
# paham : paham
# aduh : aduh
# kemanamana : kemanamana
# berhari2 : berhari2
# hidup : hidup
# simpel : simpel
# pake2 : pake2
# diisi : isi
# identitas : identitas
# message : message
# sesuaikan : sesuai
# ktp : ktp
# sepele : sepele
# kartu : kartu
# benar-benar : benar
# jualan : jual
# teros : ros
# ralyatnya : ralyatnya
# website : website
# disediakan : sedia
# kompetible : kompetible
# lanjutkan : lanjut
# pemerintahan : perintah
# mewajibkan : wajib
# initerimakasih : initerimakasih
# mudah : mudah
# 2x : 2x
# allah : allah
# paakkemarin2 : paakkemarin2
# aplnya : aplnya
# gampang : gampang
# sayatrus : sayatrus
# pembaruan : baru
# pembaruanmalah : pembaruanmalah
# susahnya : susah
# ampunsudah : ampunsudah
# 7x : 7x
# sinittp : sinittp
# bisatrus : bisatrus
# jwbn : jwbn
# androitnya : androitnya
# atasla : atasla
# androit : androit
# 50tolong : 50tolong
# pakversi : pakversi
# kaya : kaya
# gampangbuat : gampangbuat
# kerjakeluhanku : kerjakeluhanku
# pengennya : ken
# minus : minus
# angin : angin
# rumah : rumah
# wfh : wfh
# komplen : komplen
# ayo : ayo
# keamanan : aman
# diragukan : ragu
# menyedihkan : sedih
# nasional : nasional
# amatketika : amatketika
# ribuan : ribu
# lulusan : lulus
# serasa : serasa
# itsekelas : itsekelas
# deh : deh
# menge : menge
# perubahan : ubah
# bercoba : coba
# andalkan : andal
# melihat : lihat
# setujuanda : setujuanda
# barutrus : barutrus
# dieem : dieem
# ajaharus : ajaharus
# itukatanya : itukatanya
# yasdh : yasdh
# bisabagaimana : bisabagaimana
# jangkauan : jangkau
# tutup : tutup
# terkadang : terkadang
# hilang : hilang
# sinyal : sinyal
# suka : suka
# kadang : kadang
# perbaharui : baharu
# kga : kga
# tapi : tapi
# bahasa : bahasa
# warganegara : warganegara
# utkmelanjutkan : utkmelanjutkan
# prosestolong : prosestolong
# perbaikiaplikasi : perbaikiaplikasi
# inimembuat : inimembuat
# sertifikatnya : sertifikat
# berisi : isi
# kosong : kosong
# datanya : data
# perlukan : perlu
# cheklis : cheklis
# pengunaan : pengunaan
# harap : harap
# pengembang : kembang
# memperbaiki : baik
# perhatian : perhati
# kerasnya : keras
# haturkan : hatur
# ayah : ayah
# pasca : pasca
# version : version
# memperlancar : lancar
# rutinitas : rutinitas
# harian : hari
# gerakan : gera
# mall : mall
# ketahan : tahan
# mendaftar : daftar
# sekaliny : sekaliny
# menyetujuimohon : menyetujuimohon
# bagaimanakrn : bagaimanakrn
# sepertiny : sepertiny
# dilaman : dilam
# utama : utama
# permintaan : minta
# dibenah : benah
# wajib : wajib
# berpergian : pergi
# meyalahkan : meyalahkan
# taat : taat
# valid : valid
# masukan : masuk
# notlp : notlp
# nyedot : nyedot
# kuota : kuota
# fungsi : fungsi
# privsi : privsi
# istall : istall
# kebijaka : kebijaka
# nganti : nganti
# ngaruh : ngaruh
# muter2 : muter2
# menengah : tengah
# serba : serba
# keterbatasan : batas
# pantas : pantas
# gasin : gasin
# signifikan : signifikan
# sinkronisasi : sinkronisasi
# lokasi : lokasi
# terkendala : kendala
# kenyataannya : nyata
# nyandet : nyandet
# vaksinnyabilangnya : vaksinnyabilangnya
# tertulis : tulis
# tulisannya : tulis
# cuman : cuman
# membaca : baca
# crome : crome
# mengisi : isi
# nyatapi : nyatapi
# bisi : bis
# lahirjenis : lahirjenis
# kelamindan : kelamindan
# waktu : waktu
# donlot : donlot
# inisemua : inisemua
# data2 : data2
# isitrus : isitrus
# terdaftarpdhl : terdaftarpdhl
# 2xdicoba2 : 2xdicoba2
# masalah : masalah
# nyalalu : nyalalu
# iniselang : iniselang
# bulan : bulan
# harapan : harap
# nyalah : nyalah
# boro-boro : boro-boro
# mskdr : mskdr
# nyabisa : nyabisa
# munculin : munculin
# nuncul : nuncul
# step : step
# diterapkan : terap
# infrastruktur : infrastruktur
# privasimalah : privasimalah
# ditempat : tempat
# ngabisin : ngabisin
# apllikasi : apllikasi
# lupa : lupa
# mengklik : klik
# setujusimpan : setujusimpan
# form : form
# lebar : lebar
# sopan : sopan
# mengkritik : kritik
# dengar : dengar
# kasar : kasar
# keras : keras
# tangkap : tangkap
# lucu : lucu
# 12 : 12
# cek : cek
# pintar : pintar
# bodo : bodo
# stop : stop
# kebawahgak : kebawahgak
# copot : copot
# menyampah : sampah
# utuk : utuk
# kagak : kagak
# merah : merah
# kolomnya : kolom
# diuji : uji
# dirilis : rilis
# 10jt : 10jt
# rating : rating
# 36 : 36
# pengembangya : pengembangya
# mbuka : mbuka
# persaratan : sarat
# kebanyakan : banyak
# dibarengi : bareng
# pembenahan : benah
# nyentang : nyentang
# kalangan : kalang
# segede : gede
# tronton : tronton
# semut : semut
# abal : abal
# secan : secan
# lengkapi : lengkap
# najis : najis
# gua : gua
# bayak : bayak
# scolling : scolling
# berfungsi : fungsi
# memenuhi : penuh
# diperhatikan : perhati
# terkhusus : khusus
# experience : experience
# ux : ux
# dosis : dosis
# berwarna : warna
# jalan : jalan
# gedung2 : gedung2
# mal2 : mal2
# alasan : alas
# ujung2nya : ujung2nya
# duit : duit
# hadeeh : hadeeh
# buak : buak
# long : long
# cetak : cetak
# kartunya : kartu
# mendingan : mending
# 4 : 4
# ulangi : ulang
# hish : hish
# malas : malas
# aggree : aggree
# mentangmentang : mentangmentang
# jadul : jadul
# bapuk : bapuk
# bayarin : bayarin
# dinas : dinas
# menerus : terus
# link : link
# pfizer : pfizer
# selese2 : selese2
# gara-gara : gara-gara
# muncul2 : muncul2
# kominkom : kominkom
# sulit : sulit
# bingung : bingung
# sayadi : sayadi
# j7 : j7
# normal : normal
# jaya : jaya
# perfomanya : perfomanya
# gesermohon : gesermohon
# bijaksanaatau : bijaksanaatau
# mengembalikan : kembali
# hang : hang
# dihapus : hapus
# berulang : ulang
# scrol : scrol
# kinerja : kerja
# paginya : pagi
# nambo : nambo
# krl : krl
# berlokasi : lokasi
# sudirman : sudirman
# stasiun : stasiun
# mrt : mrt
# bni : bni
# bendunga : bendunga
# hilir : hilir
# tingkatin : tingkatin
# terganggu : ganggu
# hapenya : hapenya
# spek : spek
# 323 : 323
# macamjadi : macamjadi
# sertifikasi : sertifikasi
# biayai : biaya
# bos : bos
# benahi : benah
# wr : wr
# wb : wb
# selesai : selesai
# mengetik : etik
# angka : angka
# penjelasanya : jasa
# wna : wna
# enter : enter
# nkri : nkri
# kolom : kolom
# teleponnya : telepon
# tersistem : sistem
# 62 : 62
# menyelesaikan : selesai
# pendaftarannya : daftar
# srg : srg
# lolos : lolos
# karantina : karantina
# airport : airport
# penyelesaiannya : selesai
# petugas : tugas
# menjadikan : jadi
# lokal : lokal
# lempar : lempar
# luas : luas
# membebani : beban
# dunia : dunia
# logikanya : logika
# musibah : musibah
# harusnya : harus
# disederhanakan : sederhana
# kebalikannya : balik
# awaljudul : awaljudul
# menutup : tutup
# clear : clear
# chace : chace
# manual : manual
# restart : restart
# uninstalinstal : uninstalinstal
# loging : loging
# blangko : blangko
# lersetujuan : lersetujuan
# disetujui : tuju
# berpindah : pindah
# bekakali : bekakali
# pasang : pasang
# bagaiamana : bagaiamana
# loginnya : loginnya
# bamtuannya : bamtuannya
# brenti : brenti
# ksbijakanstuck : ksbijakanstuck
# disitu : situ
# mlulu : mlulu
# pedulilindingi : pedulilindingi
# buktinya : bukti
# kongsi : kongsi
# pedulilindungitolong : pedulilindungitolong
# sutuju : sutuju
# aplikadi : aplikadi
# berpegiandan : berpegiandan
# ketempat : tempat
# kurir : kurir
# terkahir : terkahir
# maps : maps
# hilangi : hilang
# menyebabkan : sebab
# memantau : pantau
# gps : gps
# wfo : wfo
# dimunculkan : muncul
# dikurangi : rang
# ampun : ampun
# diinstall : diinstall
# dtaa : dtaa
# kelauta : kelauta
# ditulis : tulis
# hijau : hijau
# sempurna : sempurna
# dikirim : kirim
# pencet : pencet
# tolak : tolak
# easy : easy
# keren : keren
# rakyatnya : rakyat
# sengaja : sengaja
# dibaca : baca
# samapai : samapai
# jafi : jafi
# munculd : munculd
# upgarde : upgarde
# androidstuck : androidstuck
# certificate : certificate
# vaccine : vaccine
# dibelikan : beli
# peraturan : atur
# permasalahan : masalah
# ulasannya : ulas
# september : september
# diarahkan : arah
# lengkap : lengkap
# sendirimuncul : sendirimuncul
# pemberitahuan : pemberitahuan
# habisjadi : habisjadi
# sign : sign
# berulangsign : berulangsign
# dibatasi : batas
# kalijika : kalijika
# kalihrs : kalihrs
# aplikasinyakalau : aplikasinyakalau
# logintolong : logintolong
# bisanya : bisa
# inisedangkan : inisedangkan
# ginimenyusahkan : ginimenyusahkan
# fro : fro
# ajg : ajg
# dibagian : bagi
# centangkok : centangkok
# jelassaya : jelassaya
# bukamemang : bukamemang
# lokalsumpah : lokalsumpah
# sayaapakah : sayaapakah
# bisasementara : bisasementara
# menukar : tukar
# bisamisal : bisamisal
# shopi : shopi
# pengeluar : keluar
# malaysia : malaysia
# indonesiaapakah : indonesiaapakah
# berpengaruh : pengaruh
# inisehingga : inisehingga
# menjijikan : jijik
# sms : sms
# allikasi : allikasi
# develop : develop
# idiot : idiot
# kera : kera
# monyet2 : monyet2
# muat : muat
# dilayar : layar
# kemana2 : kemana2
# jayalah : jaya
# tahap : tahap
# 01 : 01
# 09 : 09
# 2021vaksin : 2021vaksin
# 30 : 30
# 2021 : 2021
# ketererangan : erang
# duamohonpencerahanya : duamohonpencerahanya
# berusaha : usaha
# patuh : patuh
# pemerintahterimakasih : pemerintahterimakasih
# apa2an : apa2an
# dibutuhkan : butuh
# kekirim : kirim
# noktp : noktp
# pencerahan : cerah
# kota : kota
# pentingtp : pentingtp
# transit : transit
# lagilangsung : lagilangsung
# muncul2stelah : muncul2stelah
# waktunya : waktu
# terus : terus
# gagallog : gagallog
# surh : surh
# 17 : 17
# oktober : oktober
# tanggapan : tanggap
# otak : otak
# hargain : hargain
# pelayanan : layan
# viral : viral
# dilayanin : dilayanin
# aksesdi : aksesdi
# menyulitkan : sulit
# penggunaini : penggunaini
# barcodejadi : barcodejadi
# bermasalah : masalah
# berkunjung : kunjung
# jaringan : jaring
# kuaota : kuaota
# internet : internet
# aman : aman
# layak : layak
# birokrasi : birokrasi
# aplikasi2 : aplikasi2
# akoh : akoh
# samsek : samsek
# minimarket : minimarket
# perasaan : asa
# jadul2 : jadul2
# edit : edit
# hpy : hpy
# not : not
# found : found
# usery : usery
# keluarpas : keluarpas
# beranda : beranda
# incara : incara
# madahal : madahal
# terhubung : hubung
# kedepannya : depan
# ditingkatkan : tingkat
# kritikan : kritik
# nyuruh : nyuruh
# kerjasamanya : kerjasamanya
# logo : logo
# mene : mene
# back : back
# ditunggu : tunggu
# mincul : mincul
# wniwna : wniwna
# merespon : merespon
# menggunakannya : guna
# browser : browser
# bimbingan : bimbing
# benerbener : benerbener
# penanganan : tangan
# keluhannya : keluh
# ditolak : tolak
# sertifikatpun : sertifikat
# kejelasan : jelas
# ponsel : ponsel
# isu : isu
# memaksa : paksa
# menghidupkan : hidup
# mode : mode
# terkuras : kuras
# daerah : daerah
# pelosok : pelosok
# gangguan : ganggu
# mencari : cari
# bts : bts
# terdekat : dekat
# diulas : ulas
# darahmohon : darahmohon
# dikoreksihanya : dikoreksihanya
# sajaatau : sajaatau
# terbaruhp : terbaruhp
# lenovoa7000kita : lenovoa7000kita
# knapa : knapa
# beraturangak : beraturangak
# pegangan : pegang
# diupdte : diupdte
# terupdte : terupdte
# birukan : biru
# dibawahnya : bawah
# mulaisetuju : mulaisetuju
# screen : screen
# sizenya : sizenya
# 50 : 50
# mulaiselanjutnya : mulaiselanjutnya
# lagimohon : lagimohon
# dikembalikan : kembali
# updte : updte
# belum : belum
# dapat : dapat
# transfortasi : transfortasi
# nunjukin : nunjukin
# ngalamin : ngalamin
# dukung : dukung
# teknologi : teknologi
# teknologinya : teknologi
# samsung : samsung
# j5 : j5
# lapisan : lapis
# indak : indak
# lembar : lembar
# lamaa : lamaa
# batu : batu
# sembunyi : sembunyi
# tangan : tangan
# didownload : didownload
# pernyataan : nyata
# privasisudah : privasisudah
# menghanbat : menghanbat
# mengganggu : ganggu
# digunakkan : digunakkan
# berharap : harap
# layanan : layan
# boz : boz
# oppo : oppo
# chp1701 : chp1701
# orisinal : orisinal
# stadar : stadar
# chek : chek
# rekan2 : rekan2
# sejenis : jenis
# adaprogram : adaprogram
# boskuterimakasih : boskuterimakasih
# setujuinya : tuju
# masaiya : masaiya
# sayanya : saya
# tipe : tipe
# dipersetujuan : tuju
# sentuh : sentuh
# sembunyikan : sembunyi
# berbeda : beda
# g5 : g5
# nougat : nougat
# usap : usap
# kearah : arah
# terapkan : terap
# lenovo : lenovo
# 6000 : 6000
# ecek : ecek
# mahterimakasih : mahterimakasih
# adminnya : adminnya
# kementrian : tri
# interaktif : interaktif
# samsu : samsu
# j5waktu : j5waktu
# privasig : privasig
# agreeaplikasi : agreeaplikasi
# murah : murah
# lohayo : lohayo
# biasamengatasi : biasamengatasi
# kelluhan : kelluhan
# jadulharus : jadulharus
# solusiharus : solusiharus
# tindakan : tindak
# seribu : ribu
# bahhasa : bahhasa
# mumpung : mumpung
# gratisskalau : gratisskalau
# bayarg : bayarg
# duwet : duwet
# iniefek : iniefek
# penngurangan : penngurangan
# stres : stres
# menu : menu
# lanjutan : lanjut
# dear : dear
# adminsetelah : adminsetelah
# wassalam : wassalam
# 511 : 511
# vaksin2 : vaksin2
# kirimi : kirim
# tgl13oktober : tgl13oktober
# tes : tes
# gakeluar : gakeluar
# dm : dm
# diig : diig
# smsnya : smsnya
# pedulilindung : pedulilindung
# langsung : langsung
# berbobotsudah : berbobotsudah
# downdload : downdload
# masukdaftarini : masukdaftarini
# memperkaya : kaya
# niorang : niorang
# jaman : jaman
# sekasrang : sekasrang
# hidupnya : hidup
# atur : atur
# aplikasingaco : aplikasingaco
# dongeng : dongeng
# signal : signal
# sni : sni
# salahkan : salah
# mengaco : aco
# pendataan : data
# terdata : data
# tolol : tolol
# muak : muak
# sertifkat : sertifkat
# shi : shi
# periksa : periksa
# pengulangan : ulang
# 100 : 100
# kalinya : kali
# buar : buar
# kesabaran : sabar
# batas : batas
# pengin : pengin
# banting : banting
# 4x : 4x
# smartphone : smartphone
# blank : blank
# masukkan : masuk
# otd : otd
# dilaksanakan : laksana
# perbarui : baru
# masukkin : masukkin
# amateur : amateur
# dibisa : bisa
# bukamacet : bukamacet
# privacy : privacy
# heran : heran
# milik : milik
# kinerjanyaapa : kinerjanyaapa
# keberapa : berapa
# terbaca : baca
# passpor : passpor
# tim : tim
# rekrut : rekrut
# programer : programer
# handal : handal
# angel : angel
# vivo : vivo
# y53 : y53
# gunanya : guna
# berangkat : berangkat
# notif : notif
# memasukan : pasu
# mengulang : ulang
# diperbaikin : diperbaikin
# kontak : kontak
# teknis : teknis
# sinkronkan : sinkron
# grapari : grapari
# resmi : resmi
# informan : informan
# mentah : mentah
# low : low
# juta : juta
# cuan : cuan
# lindungiapanya : lindungiapanya
# apanya : apa
# aplikas : aplikas
# musti : musti
# persinya : pers
# komunikasi : komunikasi
# syukur : syukur
# alhmdllhbikin : alhmdllhbikin
# dulupungsi : dulupungsi
# manfaatnya : manfaat
# universal : universal
# jamah : jamah
# mengutamakan : utama
# jarang : jarang
# lancarnya : lancar
# ngeribetin : ngeribetin
# dipertimbangkan : timbang
# kompeten : kompeten
# terinstal : terinstal
# tertera : tera
# kenap : kenap
# 9 : 9
# stuk : stuk
# masuknya : masuk
# 26 : 26
# pintu : pintu
# security : security
# tertahan : tahan
# berkalikali : berkalikali
# adek : adek
# kesamaan : sama
# kayal : kayal
# ngebug : ngebug
# opsi : opsi
# cs : cs
# sejenisnya : jenis
# mengadukan : adu
# kekurangan : kurang
# terbit : terbit
# suntik : suntik
# diatas : atas
# kebijakannya : bijak
# kntor : kntor
# accpet : accpet
# menemukan : temu
# seting : ting
# size : size
# mengganti : ganti
# kecilsemoga : kecilsemoga
# websitenya : websitenya
# 19 : 19
# 23 : 23
# statusnya : status
# akunnya : akun
# dikirimkirim : dikirimkirim
# vaksinnya : vaksin
# web : web
# tibatiba : tibatiba
# percepat : cepat
# perbaikannya : baik
# stak : stak
# termcondition : termcondition
# script : script
# masuk2 : masuk2
# lainapa : lainapa
# kaki : kaki
# kendaraan : kendara
# 2udah : 2udah
# tutorial : tutorial
# yt : yt
# vaksineh : vaksineh
# pedlindunginya : pedlindunginya
# unfaedah : unfaedah
# kualitas : kualitas
# s6 : s6
# perbaikilah : baik
# syaratsyaratnya : syaratsyaratnya
# lindunginya : lindung
# beberapa : beberapa
# installuninstall : installuninstall
# bergeser : geser
# diproses : proses
# ngulang : ngulang
# bayangkan : bayang
# darurat : darurat
# penerbangan : terbang
# papah : papah
# 720x1280pixel : 720x1280pixel
# kepotong : potong
# adik : adik
# 720x1520px : 720x1520px
# stabil : stabil
# diluar : luar
# jangakauan : jangakauan
# area : area
# berkwalitas : berkwalitas
# okt : okt
# gsm : gsm
# terverifikasi : verifikasi
# dianggap : anggap
# kadaluarsa : kadaluarsa
# time : time
# selalu : selalu
# rezeki : rezeki
# perkara : perkara
# genah : genah
# popup : popup
# pop : pop
# up : up
# v6 : v6
# restore : restore
# apaapaan : apaapaan
# ribetstuck : ribetstuck
# nasib : nasib
# ojol : ojol
# sesimple : sesimple
# simple : simple
# miskin : miskin
# dimasa : masa
# mikir : mikir
# 1000x : 1000x
# bpkibu : bpkibu
# pikirkan : pikir
# bilangnya : bilang
# itupun : itu
# dtrima : dtrima
# terdesak : desak
# orang : orang
# pemeriksaan : periksa
# contohnya : contoh
# aplikasitapi : aplikasitapi
# bisasetelah : bisasetelah
# dekatgimana : dekatgimana
# hrsx : hrsx
# ruwet : ruwet
# menghabiskan : habis
# dana : dana
# dikoreksi : koreksi
# gaptek : gaptek
# ahlak : ahlak
# muluh : muluh
# nyusahi : nyusahi
# mengapresiasi : apresiasi
# eksekusi : eksekusi
# lapangan : lapang
# protokol : protokol
# disiapkan : siap
# payung : payung
# hukum : hukum
# menindak : tindak
# pelanggar : langgar
# prokes : prokes
# ditegakkan : tegak
# diviralkan : diviralkan
# mencegah : cegah
# gelombang : gelombang
# v402 : v402
# beberapaversi : beberapaversi
# relogin : relogin
# chekout : chekout
# sehinga : sehinga
# stag : stag
# chekin : chekin
# dihari : hari
# revisinya : revisi
# haadeeuuh : haadeeuuh
# informasi : informasi
# paksin : paksin
# istri : istri
# jadulmau : jadulmau
# prakerja : prakerja
# diterima : terima
# nonaktifkandapet : nonaktifkandapet
# php : php
# ehac : ehac
# domestik : domestik
# saudara : saudara
# agustus : agustus
# muncultelpon : muncultelpon
# terdataaplikasi : terdataaplikasi
# inti : inti
# nyamasa : nyamasa
# pasar : pasar
# minggu : minggu
# ajaterus : ajaterus
# ajtempat : ajtempat
# barkod : barkod
# outmasak : outmasak
# sendiribukan : sendiribukan
# jendela : jendela
# ketersediaan : sedia
# masal : masal
# sajagx : sajagx
# haruskah : harus
# tidan : tidan
# kedalam : dalam
# melanjutkannya : lanjut
# gerangan : gerangan
# dasar : dasar
# bank : bank
# dipencet : pencet
# sertif : sertif
# formulir : formulir
# konfirmasi : konfirmasi
# tombolnya : tombol
# abu2 : abu2
# terisi : isi
# disesuaikan : sesuai
# kanpa : kanpa
# bukapertama : bukapertama
# aya : aya
# masukcoba : masukcoba
# permudah : mudah
# persulit : sulit
# andoid : andoid
# tega : tega
# puas : puas
# sdang : sdang
# offline : offline
# trlebih : trlebih
# sndrierror : sndrierror
# mngaktifkan : mngaktifkan
# lokasitdak : lokasitdak
# seperti : seperti
# dengan : dengan
# mysejahtera : mysejahtera
# offlinesya : offlinesya
# kdepanya : kdepanya
# lebih : lebih
# sebelumnya : belum
# kekantor : kantor
# situ : situ
# terang : terang
# solusinyabapak : solusinyabapak
# text : text
# ubah : ubah
# j1 : j1
# mini : mini
# assalamu : assalamu
# alaikumkenapa : alaikumkenapa
# loginsetelah : loginsetelah
# malam : malam
# google : google
# setujutidak : setujutidak
# option : option
# bu : bu
# gantibeli : gantibeli
# beraktivitas : aktivitas
# ruangan : ruang
# kuning : kuning
# warnanya : warna
# buruan : buru
# pergi : pergi
# main : main
# sepakbola : sepakbola
# liga : liga
# kotaterimakasih : kotaterimakasih
# rapid : rapid
# contak : contak
# stts : stts
# bukapadahal : bukapadahal
# nihbuka : nihbuka
# ajadi : ajadi
# reload : reload
# 10x : 10x
# jugabuka : jugabuka
# petunjuk : tunjuk
# bukahehe : bukahehe
# diupgrade : diupgrade
# kira-kira : kira
# toleransi : toleransi
# urusannya : urus
# 55 : 55
# inch : inch
# belanja : belanja
# supermarket : supermarket
# ngeselintombol : ngeselintombol
# atashanya : atashanya
# nongol : nongol
# sedikithu : sedikithu
# payahaplikasi : payahaplikasi
# rilisterllu : rilisterllu
# kanmerepot : kanmerepot
# pengalaman : alam
# pesan : pesan
# tua : tua
# pengetikan : keti
# keliru : keliru
# lahirnya : lahir
# kertas : kertas
# kekeliruan : keliru
# bela : bela
# membela : bela
# smuah : smuah
# ktahan : ktahan
# nyangkut : nyangkut
# teks : teks
# super : super
# 25 : 25
# menyetuji : tuji
# ui : ui
# resolusi : resolusi
# kecilsaya : kecilsaya
# dapaf : dapaf
# dikembangkan : kembang
# kecilterima : kecilterima
# digembor2in : digembor2in
# munculnya : muncul
# sertiffikatnyaa : sertiffikatnyaa
# menkominfo : menkominfo
# dijalanin : dijalanin
# storage : storage
# kepenuhan : penuh
# pecah : pecah
# beda : beda
# pendapat : dapat
# mengasingkan : asing
# menghancurkan : hancur
# cook : cook
# anjir : anjir
# lancar : lancar
# jelaas : jelaas
# setan : setan
# nomer : nomer
# kecilnya : kecil
# nginput : nginput
# sebulan : bulan
# munculhanya : munculhanya
# munculditelepon : munculditelepon
# muncultapi : muncultapi
# 2tidak : 2tidak
# responnya : responnya
# next : next
# disekolah : seko
# 0 : 0
# kukasi : kas
# narok : narok
# gambarnya : gambar
# teken : teken
# ngapa : ngapa
# uinstall : uinstall
# shp : shp
# ram : ram
# 2gb : 2gb
# playstoresemua : playstoresemua
# keterpaksaanoleh : keterpaksaanoleh
# itubagi : itubagi
# bayar : bayar
# akibatnya : akibat
# alam : alam
# buk : buk
# evan : evan
# pelajar : ajar
# guru : guru
# bersangkutan : sangkut
# kunjungi : kunjung
# mempermuda : muda
# padal : padal
# emailnya : email
# laporan : lapor
# mengayomi : ayom
# bertanggung : tanggung
# kinerjanya : kerja
# rutin : rutin
# a37 : a37
# dscroll : dscroll
# sebelum : belum
# mnghbat : mnghbat
# pribumi : pribumi
# rejeki : rejeki
# terbuka : buka
# kebijaksanaan : bijaksana
# aksesnya : akses
# donwload : donwload
# syarat2 : syarat2
# privasitolong : privasitolong
# membenarkan : benar
# persulitsaya : persulitsaya
# jadi2 : jadi2
# sore : sore
# sayatolong : sayatolong
# inisangat : inisangat
# dianjurkan : anjur
# neo : neo
# juga : juga
# sakit : sakit
# pusat : pusat
# medis : medis
# terdeteksi : deteksi
# palsu : palsu
# bussway : bussway
# digunain : digunain
# menghilang : hilang
# disebabkan : sebab
# icon : icon
# diharuskan : harus
# persiapkan : siap
# bosan : bosan
# sesion : sesion
# expired : expired
# home : home
# expire : expire
# release : release
# yahabis : yahabis
# wniabis : wniabis
# ajastlh : ajastlh
# gimanakoq : gimanakoq
# selanjutnyaapa : selanjutnyaapa
# tampilannya : tampil
# ditinjau : tinjau
# validasi : validasi
# kelas : kelas
# dirjen : dirjen
# menangani : tangan
# ahlinya : ahli
# komputer : komputer
# arah : arah
# warung : warung
# lapak2 : lapak2
# konsultasi : konsultasi
# kehapus : hapus
# rumit : rumit
# dioperasikan : operasi
# diverifikasi : verifikasi
# pengertiannya : erti
# pedulilindungiak : pedulilindungiak
# sertifikatvaksin : sertifikatvaksin
# bulantrs : bulantrs
# aku : aku
# kerestardh : kerestardh
# sertifikatnyagi : sertifikatnyagi
# bisa : bisa
# darilokasi : darilokasi
# jabingan : jabingan
# coek : coek
# ketidaknyamanan : ketidaknyamanan
# tak : tak
# suuw : suuw
# privasinya : privasi
# akhirny : akhirny
# atik : atik
# sekian : sekian
# klr : klr
# swalayan : swalayan
# terjebak : jebak
# gunasudah : gunasudah
# srtifikat : srtifikat
# jugapadahal : jugapadahal
# mengurus : urus
# pemerintahanmakin : pemerintahanmakin
# gembelminta : gembelminta
# isinya : isi
# doangjiamput : doangjiamput
# susahtolong : susahtolong
# dibenahin : dibenahin
# lambat : lambat
# asli : asli
# 15 : 15
# tab : tab
# serfltifikat : serfltifikat
# muter : muter
# loading : loading
# inipadahal : inipadahal
# satupun : satu
# didalam : dalam
# lancarsinyal : lancarsinyal
# 4g : 4g
# gambar : gambar
# masih : masih
# nmer : nmer
# apasi : apas
# sumpada : sumpada
# relevan : relevan
# busuk : busuk
# pertimbangan : timbang
# kedepan : depan
# kekuranganya : kekuranganya
# bingungribet : bingungribet
# nampaknya : nampaknya
# pendaftaran : daftar
# situs : situs
# webnya : webnya
# emm : emm
# responsif : responsif
# improve : improve
# menampung : tampung
# kebijakn : kebijakn
# selanjutny : selanjutny
# interfacenya : interfacenya
# 5okt2021 : 5okt2021
# 119 : 119
# kemna2buat : kemna2buat
# melamar : lamar
# whai : whai
# percaya : percaya
# dipaksa : paksa
# kemenkes : kemenkes
# administras : administras
# diharuskanwajibkan : diharuskanwajibkan
# lelet : lelet
# kenpa : kenpa
# diketerangan : terang
# 28 : 28
# 27 : 27
# pengguanaan : pengguanaan
# capedeh : capedeh
# keluar2 : keluar2
# duanya : dua
# nakes : nakes
# 231021 : 231021
# anjuran : anjur
# turuti : turut
# kendalah : kendalah
# instansi : instansi
# memaksakan : paksa
# kaami : kaami
# bacaa : bacaa
# bacaan : baca
# pleasediperbaiki : pleasediperbaiki
# zaman : zaman
# mmbutuhkan : mmbutuhkan
# saiki : saiki
# ora : ora
# isoh : isoh
# inkepiye : inkepiye
# ndang : ndang
# dandani : dandan
# cerdas : cerdas
# macet : macet
# pembuatan : buat
# koruptor : koruptor
# pintarnya : pintar
# miris : miris
# kelanjutannyatolong : kelanjutannyatolong
# donwlod : donwlod
# negaraan : negara
# scrool : scrool
# disalahin : disalahin
# verivikasi : verivikasi
# 711 : 711
# sampei : sampei
# perjanjian : janji
# dideteksi : deteksi
# nyalain : nyalain
# tipu : tipu
# rate : rate
# nonaktifkan : nonaktif
# rilis : rilis
# pengelolaan : kelola
# pembiayaan : biaya
# jad : jad
# hei : hei
# donlowd : donlowd
# tulisqn : tulisqn
# kewarga : warga
# adil : adil
# bjsa : bjsa
# pemilihan : pilih
# boks : boks
# ayolahh : ayolahh
# kolot : kolot
# bantuanya : bantuanya
# inj : inj
# evaluasi : evaluasi
# didalamnya : dalam
# capek : capek
# lain : lain
# ditanyak : ditanyak
# ntahlah : ntahlah
# tpibgak : tpibgak
# jadikan : jadi
# sepenuhnya : sepenuh
# sayang : sayang
# anggarannya : anggar
# sertifikaf : sertifikaf
# divaksin : vaksin
# mengunduh : unduh
# mana2 : mana2
# yakasih : yakasih
# iniuntuk : iniuntuk
# sesusah : susah
# matikan : mati
# agak : agak
# kwlanjutan : kwlanjutan
# mengahambat : mengahambat
# lag : lag
# lewati : lewat
# naikin : naikin
# dibukapada : dibukapada
# kebijakannyaga : kebijakannyaga
# nekan : nekan
# setujukepotong : setujukepotong
# kelihatan : lihat
# updatedata : updatedata
# semuaapk : semuaapk
# bingungtolong : bingungtolong
# mumpuni : mumpuni
# minsebagian : minsebagian
# inikasian : inikasian
# kepentigan : kepentigan
# lainnyajugaan : lainnyajugaan
# bekerjasama : bekerjasama
# lembaga : lembaga
# amplikasi : amplikasi
# sertikat : sertikat
# bohongan : bohong
# gaya : gaya
# bersertifikat : sertifikat
# cuek : cuek
# bebek : bebek
# komplin : komplin
# pojok : pojok
# kanan : kanan
# developmentnya : developmentnya
# codingannya : codingannya
# tap : tap
# rotate : rotate
# kayaknya : kayak
# bocah : bocah
# magang : magang
# menulis : tulis
# enggak usah : enggak usah
# penduduk : duduk
# mendata : data
# terustolong : terustolong
# dibantusaya : dibantusaya
# kehidupan : hidup
# sayadaftarnya : sayadaftarnya
# bagusaplikasi : bagusaplikasi
# diimbangi : imbang
# server : server
# tertunda : tunda
# perihal : perihal
# bgsd : bgsd
# basway : basway
# dong : dong
# stay : stay
# jakarta : jakarta
# mal : mal
# perduli : duli
# menuh2in : menuh2in
# memory : memory
# kayanya : kaya
# dibenerin : dibenerin
# detek : detek
# padalah : pada
# urus : urus
# saja : saja
# efektif : efektif
# berubah : ubah
# anggap : anggap
# profile : profile
# berubah2 : berubah2
# asalnya : asal
# menerbitkan : terbit
# sertifikatperlu : sertifikatperlu
# kajian : kaji
# lintas : lintas
# mendeteksi : deteksi
# palsumaksudnya : palsumaksudnya
# aplikator : aplikator
# mabok : mabok
# 2xmau : 2xmau
# membetulkan : betul
# dilanjut : lanjut
# koneksi : koneksi
# kecepatan : cepat
# click : click
# baiki : baik
# berasa : asa
# bohongin : bohongin
# sampainsekarang : sampainsekarang
# bisanik : bisanik
# namakatanya : namakatanya
# dukcapil : dukcapil
# mengeluarkan : keluar
# kelancaran : lancar
# ambil : ambil
# order : order
# penggunanyabanyak : penggunanyabanyak
# kamidari : kamidari
# banyaknya : banyak
# kayk : kayk
# ginisungguh : ginisungguh
# membagongkan : bagong
# diapk : diapk
# kepake : kepake
# disaat : saat
# berlanjut : lanjut
# pembodohan : bodoh
# kompatible : kompatible
# terlanjur : lanjur
# kredit : kredit
# ulangg : ulangg
# management : management
# malumaluin : malumaluin
# memperkecil : kecil
# anroid : anroid
# 7bisanya : 7bisanya
# 8masa : 8masa
# lgmna : lgmna
# susah2nyakl : susah2nyakl
# scansdangkan : scansdangkan
# kmn2 : kmn2
# scanjd : scanjd
# inijngn : inijngn
# susahkita : susahkita
# plikasisuma : plikasisuma
# prifasi : prifasi
# ketahap : tahap
# berikutnyamohon : berikutnyamohon
# satunya : satu
# beresin : resin
# ratingnya : ratingnya
# ada : ada
# setujunya : tuju
# terpaksa : paksa
# donlod : donlod
# 45 : 45
# diperbaikai : diperbaikai
# loginkok : loginkok
# ijin : ijin
# file : file
# foto : foto
# maksudnyakok : maksudnyakok
# sayamau : sayamau
# payahbikin : payahbikin
# covid19 : covid19
# korban : korban
# kefasilitas : fasilitas
# person : person
# ketemu : ketemu
# 3s : 3s
# kik : kik
# padah : padah
# bertukar : tukar
# namanya : nama
# mengatasi : atas
# copy : copy
# paste : paste
# bintangnya : bintang
# all : all
# mengecek : ecek
# front : front
# keciltolong : keciltolong
# agreement : agreement
# down : down
# anehbutuh : anehbutuh
# masuknyagak : masuknyagak
# kemana-mana : mana
# krtu : krtu
# ilg : ilg
# lgmo : lgmo
# tnda : tnda
# cobatolong : cobatolong
# tahi : tahi
# valiadsinperjalanan : valiadsinperjalanan
# penerbangagn : penerbangagn
# kompleks : kompleks
# bingungterutama : bingungterutama
# level : level
# ppkmsgt : ppkmsgt
# sukit : sukit
# sekali : sekali
# tujuanasal : tujuanasal
# ppkm : ppkm
# berapa : berapa
# mnemtukan : mnemtukan
# jnapa : jnapa
# integrasikan : integrasi
# bandara : bandara
# segingga : segingga
# antigenmengingt : antigenmengingt
# mhal : mhal
# sediri : diri
# pertanggung : tanggung
# daftartpi : daftartpi
# masukdan : masukdan
# ujung-ujung : ujung
# masukaplikasi : masukaplikasi
# apalah : apa
# inigk : inigk
# nytolong : nytolong
# dongmaksihh : dongmaksihh
# upgade : upgade
# hadeuuhh : hadeuuhh
# baim : baim
# lelah : lelah
# puyeng : puyeng
# napasihh : napasihh
# situnya : situ
# pertamaa : pertamaa
# hijauu : hijauu
# semalam : malam
# berujung : ujung
# ujian : uji
# pendadaran : dadar
# paksakan : paksa
# aktifkan : aktif
# kankaya : kankaya
# dievaluasi : evaluasi
# interface : interface
# j2 : j2
# core : core
# dibukasudah : dibukasudah
# keduadata : keduadata
# lengkaptolong : lengkaptolong
# pakehanya : pakehanya
# persetujuansetelah : persetujuansetelah
# lgbuat : lgbuat
# zonasi : zonasi
# keluarkan : keluar
# sayacoba : sayacoba
# telat : telat
# mengantri : antri
# kuat : kuat
# dilanjutin : dilanjutin
# disuru : disuru
# bisaapplikasi : bisaapplikasi
# gandoong : gandoong
# bisaok : bisaok
# penggunanyabukannya : penggunanyabukannya
# mempermudahsampai : mempermudahsampai
# susahaplikasi : susahaplikasi
# mahal : mahal
# bagus-bagus : bagus
# dikirimkan : kirim
# device : device
# galaxy : galaxy
# j6 : j6
# keperluan : perlu
# lancarr : lancarr
# iniko : iniko
# tingkatan : tingkat
# kwalitas : kwalitas
# maluin : maluin
# ibuk : ibuk
# tambah : tambah
# inbug : inbug
# gimanamohon : gimanamohon
# perbaikisoalnya : perbaikisoalnya
# action : action
# diinstal : diinstal
# uinstal : uinstal
# disuara : suara
# kelola : kelola
# duluan : duluan
# sebenerny : sebenerny
# kalaw : kalaw
# instan : instan
# freekalaw : freekalaw
# kenakan : kena
# biaya : biaya
# berbisnis : bisnis
# didunia : dunia
# kalinik : kalinik
# moll : moll
# daftr : daftr
# 240dpi : 240dpi
# game : game
# international : international
# indikator : indikator
# kerabat : kerabat
# erat : erat
# id : id
# ceritanya : cerita
# memperbaharui : baharu
# 1dan2 : 1dan2
# negaranggak : negaranggak
# berubahjadi : berubahjadi
# lindungitolong : lindungitolong
# ini : ini
# penyempurnaan : sempurna
# dicekout : dicekout
# maj : maj
# bambang : bambang
# inibikin : inibikin
# bijak : bijak
# sia : sia
# dipilih : pilih
# ajaterimah : ajaterimah
# perintahtlh : perintahtlh
# masyarakatuntukvaksindan : masyarakatuntukvaksindan
# kepada : kepada
# kesehatansdhpedulimasyarakat : kesehatansdhpedulimasyarakat
# umunnya : umun
# sepenting : penting
# nanpilin : nanpilin
# kirimmasuk : kirimmasuk
# pakibu : pakibu
# plz : plz
# jdinya : jdinya
# satu : satu
# orgkn : orgkn
# ksihn : ksihn
# vaksinya : vaksinya
# perbaruan : baru
# berikutnyabgmn : berikutnyabgmn
# mengira : ira
# ternyata : nyata
# seriusan : serius
# jwaban : jwaban
# malah : malah
# kmbli : kmbli
# scand : scand
# barcodenya : barcodenya
# jawabannya : jawab
# usul : usul
# tambahkan : tambah
# konon : konon
# haram : haram
# kadaluarsanya : kadaluarsanya
# 2tapi : 2tapi
# amezing : amezing
# pokoknya : pokok
# haya : haya
# indah : indah
# pokokoke : pokokoke
# rausah : rausah
# ngene : ngene
# babar : babar
# blas : blas
# kesehariannamun : kesehariannamun
# peningkatan : tingkat
# aksesketika : aksesketika
# inicuma : inicuma
# privasii : privasi
# gimanakalau : gimanakalau
# enggak mau : enggak mau
# dowlod : dowlod
# perkecil : kecil
# memepersulit : sulit
# sarananya : sarana
# jalanpadahal : jalanpadahal
# downlodmasih : downlodmasih
# samakenapa : samakenapa
# yaapa : yaapa
# sikomo : sikomo
# yajadi : yajadi
# kelanjutan : lanjut
# gmail : gmail
# balas : balas
# smartphonenya : smartphonenya
# suporttapi : suporttapi
# chekintunggu : chekintunggu
# masukk : masukk
# aplikasii : aplikasi
# dipermudah : mudah
# namapas : namapas
# lagihadeh : lagihadeh
# star : star
# hpsamsung : hpsamsung
# ace : ace
# erorr : erorr
# membanyaki : banyak
# maintenance : maintenance
# matang : matang
# sihaku : sihaku
# munculga : munculga
# bngtapa : bngtapa
# keberpihakan : pihak
# omong : omong
# yakkebijakan : yakkebijakan
# muluga : muluga
# youtubetolong : youtubetolong
# jantumkan : jantumkan
# costumer : costumer
# servis : servis
# nomornyaa : nomornyaa
# ngapa2in : ngapa2in
# keluarkok : keluarkok
# terpotong : potong
# ssh : ssh
# satpam : satpam
# nongolnongol : nongolnongol
# full : full
# pindah : pindah
# gedean : gede
# nyatolol : nyatolol
# qode : qode
# yud : yud
# melengkapi : lengkap
# tinggal : tinggal
# masukankenapaasusah : masukankenapaasusah
# bngtsangat : bngtsangat
# scane : scane
# nomet : nomet
# sertigikat : sertigikat
# mind : mind
# daftarkan : daftar
# pantesan : pantesan
# sembarangan : sembarang
# lindungnya : lindung
# menyesal : sesal
# updatesampe : updatesampe
# tanggaoi : tanggaoi
# terkhir : terkhir
# trouble : trouble
# efisien : efisien
# dihape : dihape
# rusak : rusak
# dongmau : dongmau
# nope : nope
# dimasukkan : masuk
# tampilanya : tampilanya
# tercrop : tercrop
# res : res
# 916 : 916
# rasis : ras
# diumpetin : diumpetin
# bodohnya : bodoh
# korup : korup
# masuklogin : masuklogin
# pabrik : pabrik
# lgkok : lgkok
# ngisi : ngisi
# jari : jari
# gempor : gempor
# mundur : mundur
# manualmau : manualmau
# kampung : kampung
# mempersulitlah : sulit
# beralasan : alas
# mengantisipasi : antisipasi
# puluhan : puluh
# lawak : lawak
# repotinbiasanya : repotinbiasanya
# logintiba2 : logintiba2
# diaksesmau : diaksesmau
# terusbsjevebah : terusbsjevebah
# sertifikatsdh : sertifikatsdh
# terbarumerasa : terbarumerasa
# sajaterimakasih : sajaterimakasih
# tba2 : tba2
# mnyusahkan : mnyusahkan
# masyarakatkmna2 : masyarakatkmna2
# initpi : initpi
# gunakangmna : gunakangmna
# donlodpercuma : donlodpercuma
# jugadi : jugadi
# aplikasinyaga : aplikasinyaga
# aflikasi : aflikasi
# donlohot : donlohot
# penjelasan : jelas
# terimakasi : terimakasi
# lulus : lulus
# uji : uji
# betulin : betulin
# klokaya : klokaya
# kelurahan : lurah
# manggadua : manggadua
# selatan : selatan
# dicatat : catat
# diaplikasi : aplikasi
# catatan : catat
# sertivikatnya : sertivikatnya
# lnjut : lnjut
# mana : mana
# keseringan : sering
# date : date
# gunain : gunain
# nyagmn : nyagmn
# nasip : nasip
# ganguan : ganguan
# kelanjutannyakayanya : kelanjutannyakayanya
# seteleh : teh
# meningkat : tingkat
# huuh : huuh
# loadingnya : loadingnya
# bgtknp : bgtknp
# agreetrus : agreetrus
# gimama : gimama
# daftarny : daftarny
# meneruskan : terus
# menyesuaikan : sesuai
# malu-malui : malu
# andalan : andal
# aktifasi : aktifasi
# birumenu : birumenu
# penguna : penguna
# maximal : maximal
# andoidnya : andoidnya
# wae : wae
# nampil : nampil
# buset : buset
# diperkecil : kecil
# vaksingimana : vaksingimana
# kesana : kesana
# zonk : zonk
# ngumpet : ngumpet
# padaha : padaha
# fitriana : fitriana
# 1warga : 1warga
# 2langkah : 2langkah
# mengeklik : klik
# 25102021 : 25102021
# masmba : masmba
# aplilasinya : aplilasinya
# mengirim : kirim
# otpnya : otpnya
# keburu : keburu
# bukaudah : bukaudah
# tlpn : tlpn
# imael : imael
# inisekalinya : inisekalinya
# terdaptar : terdaptar
# responsive : responsive
# kemanakemana : kemanakemana
# unistal : unistal
# pindahin : pindahin
# pergian : pergi
# bukagak : bukagak
# diperbaruhi : baruh
# jrnis : jrnis
# bego : bego
# aplikasimasa : aplikasimasa
# vaksinkalau : vaksinkalau
# solitare : solitare
# tampilanperbesaran : tampilanperbesaran
# dwonload : dwonload
# syaratketentuansaya : syaratketentuansaya
# prsyaratanabis : prsyaratanabis
# diapa-apai : apa
# a01 : a01
# masukdg : masukdg
# ket : ket
# habisjika : habisjika
# lemah : lemah
# melayani : layan
# anggarkan : anggar
# bayarkan : bayar
# pajak : pajak
# pengembangnya : kembang
# pengembanganya : pengembanganya
# separo : paro
# kredibil : kredibil
# jadj : jadj
# pengunanya : pengunanya
# 2bulan : 2bulan
# lgmalah : lgmalah
# privasisetelahnitu : privasisetelahnitu
# apaini : apaini
# aplikasipdahal : aplikasipdahal
# tolongdong : tolongdong
# tindaklanjuti : tindaklanjuti
# pengelola : kelola
# bad : bad
# updet : updet
# ruang : ruang
# kondisi : kondisi
# bermanfaat : manfaat
# muncuk : muncuk
# lakukan : laku
# memeriksa : periksa
# monitoring : monitoring
# penyebaran : sebar
# thx : thx
# bukatolong : bukatolong
# perbaikiklo : perbaikiklo
# bpkibumau : bpkibumau
# apliksi : apliksi
# aplikasia : aplikasia
# alhasil : alhasil
# gantung : gantung
# diapaapain : diapaapain
# tampil : tampil
# sajagak : sajagak
# selanjutnyakenapaburuk : selanjutnyakenapaburuk
# vajsin : vajsin
# munculparah : munculparah
# soremaaf : soremaaf
# positif : positif
# 29 : 29
# sep : sep
# diakun : akun
# lainmungkin : lainmungkin
# bodoh : bodoh
# agrement : agrement
# bapk : bapk
# menteri : menteri
# dibalas : balas
# traffic : traffic
# dibener : dibener
# ...
# masukjadi : masukjadi
# sarankan : saran
# tadainya : tadainya
# terselesaikan : selesai
# dikecilin : dikecilin
# baiknya : baik
# hanpir : hanpir
# terkecoh : kecoh
# total : total
# pemasangan : pasang
# ngelag : ngelag
# menemuinya : temu
# lingkungan : lingkung
# kesulitankarena : kesulitankarena
# kelahiran : lahir
# otomatiskan : otomatis
# tahun : tahun
# 2000 : 2000
# calendernya : calendernya
# lamathx : lamathx
# bagusmembantu : bagusmembantu
# menyimpan : simpan
# munculapakah : munculapakah
# kebijakanprivasi : kebijakanprivasi
# settingpengaturan : settingpengaturan
# iphone : iphone
# been : been
# fixed : fixed
# with : with
# recent : recent
# hearing : hearing
# mengertimenyetujui : mengertimenyetujui
# terlihatlayar : terlihatlayar
# landscape : landscape
# ditanggapi : tanggap
# setara : tara
# wisata : wisata
# melarang : larang
# screening : screening
# mejaga : mejaga
# hapussoalnya : hapussoalnya
# ulusan : ulusan
# lebihnya : lebih
# wassalamualaikum : wassalamualaikum
# ajik : ajik
# dominan : dominan
# maju : maju
# diselesaikan : selesai
# barunya : baru
# posisinya : posisi
# penulisan : tulis
# vakain : vakain
# merubah : rubah
# keluaryg : keluaryg
# pertamaitu : pertamaitu
# pertanyakantolong : pertanyakantolong
# jawabterimakasih : jawabterimakasih
# evaksin : evaksin
# lindungipadahal : lindungipadahal
# 2tolong : 2tolong
# banahi : banahi
# sistemnyadi : sistemnyadi
# penjelasannyamakasih : penjelasannyamakasih
# pencegahan : cegah
# patuhi : patuh
# prokesdan : prokesdan
# cpat : cpat
# sertifikad : sertifikad
# soyang : soyang
# verry : verry
# udara : udara
# anaknya : anak
# bawahpokoknya : bawahpokoknya
# emailyg : emailyg
# komenanku : komenanku
# berkerumun : kerumun
# masker : masker
# dsbadyg : dsbadyg
# perkampungan : kampung
# upacara : upacara
# memperingatkan : ingat
# merindukan : rindu
# pejabat : jabat
# 34 : 34
# pemuda : pemuda
# dewasa : dewasa
# bermain : main
# sepak : sepak
# bola : bola
# perumahan : rumah
# kampung2apa : kampung2apa
# diperhatikannyatolonglah : diperhatikannyatolonglah
# mari : mari
# berantas : berantas
# covik : covik
# masingmasing : masingmasing
# bangkit : bangkit
# mengupdate : mengupdate
# berita : berita
# bpk : bpk
# presiden : presiden
# jokowi : jokowi
# sehatkan : sehat
# beredar : edar
# kabar : kabar
# dkk : dkk
# vaksinnyasudah : vaksinnyasudah
# lindungiterimakasih : lindungiterimakasih
# kampus : kampus
# bosa : bosa
# dihubungin : dihubungin
# belajar : ajar
# ngotak : ngotak
# ngatik : ngatik
# masukanmasuk : masukanmasuk
# penghapusan : hapus
# nama2 : nama2
# suratnya : surat
# ketinggalan : tinggal
# dirumah : rumah
# tunjukkan : tunjuk
# pemberantasan : berantas
# allhamdulilah : allhamdulilah
# keluarnya : keluar
# tanggalnya : tanggal
# pindai : pindai
# downlooad : downlooad
# tercatat : catat
# ramahpokoknya : ramahpokoknya
# merapat : rapat
# terhindar : hindar
# virussalam : virussalam
# xl : xl
# simpati : simpati
# kiriman : kirim
# gogle : gogle
# stelan : stelan
# direset : direset
# profilnya : profil
# kapital : kapital
# munculapa : munculapa
# fontukuran : fontukuran
# produk : produk
# bumn : bumn
# produknya : produk
# komentar : komentar
# urusanku : urus
# lagiterutama : lagiterutama
# singkron : singkron
# dicegah : cegah
# sirna : sirna
# muka : muka
# bumi : bumi
# beribadah : ibadah
# vaksinharus : vaksinharus
# laenjdi : laenjdi
# gunakangi : gunakangi
# 19lebih : 19lebih
# amanmudah : amanmudah
# membaik : baik
# bersatu : satu
# teguh : teguh
# bercerai : cerai
# runtuh : runtuh
# mengorbankan : korban
# keberlangsungan : langsung
# pelaksanaan : laksana
# menyeluruhterimakasih : menyeluruhterimakasih
# sayadan : sayadan
# transjakarta : transjakarta
# lagiperbaiki : lagiperbaiki
# telpwa : telpwa
# seputar : putar
# temantapi : temantapi
# dapatsertipikat : dapatsertipikat
# nyaemang : nyaemang
# masalahtetapi : masalahtetapi
# apknyagimana : apknyagimana
# keteranganya : keteranganya
# sertfikat : sertfikat
# sabgat : sabgat
# menunjukan : tunjuk
# depeloper : depeloper
# genta : genta
# wahyu : wahyu
# susilo : susilo
# masukseseudah : masukseseudah
# upgred : upgred
# barususah : barususah
# nyapas : nyapas
# munculaduhpedulilindungi : munculaduhpedulilindungi
# lamadi : lamadi
# keringat : keringat
# dingin : dingin
# nyerahcoba : nyerahcoba
# unduhdownload : unduhdownload
# tiktok : tiktok
# kurangi : kurang
# micin : micin
# kapasitasorg : kapasitasorg
# rajin-rajin : rajin
# outstanding : outstanding
# terbukabaiknya : terbukabaiknya
# mendekati : dekat
# sajaaplikasi : sajaaplikasi
# berkaitan : kait
# 14102021 : 14102021
# membawa : bawa
# pedulilindungisaya : pedulilindungisaya
# indonesiatrus : indonesiatrus
# terintegrasi : integrasi
# obat : obat
# perawatan : awat
# covidnya : covidnya
# inginkankalo : inginkankalo
# terkaitatas : terkaitatas
# keluargasemoga : keluargasemoga
# sip : sip
# dicari : cari
# sistemmakasihmohon : sistemmakasihmohon
# screnshot : screnshot
# thickbox : thickbox
# tetkirim : tetkirim
# bukan : bukan
# sangatt : sangatt
# mudahh : mudahh
# hebat : hebat
# bohong : bohong
# terbaiksangat : terbaiksangat
# pedulilindungigak : pedulilindungigak
# repot-repot : repot
# berubahisinya : berubahisinya
# iniyasaya : iniyasaya
# inimungkin : inimungkin
# perkembangan : kembang
# bilang : bilang
# smart : smart
# vacsin : vacsin
# asmudi : asmudi
# october : october
# dapatkan : dapat
# baguscuma : baguscuma
# kalowarna : kalowarna
# hijautapi : hijautapi
# bloon : bloon
# 8gb : 8gb
# enggak bakal : enggak bakal
# blok : blok
# bappa : bappa
# hi : hi
# j5pro : j5pro
# diperbaikiterimakasih : diperbaikiterimakasih
# send : send
# diabaikan : abai
# periodik : periodik
# erase : erase
# 4jam : 4jam
# smuanya : smuanya
# deki : dek
# kemajuan : maju
# dituruti : turut
# sarana : sarana
# upaya : upaya
# kepedulian : peduli
# setel : setel
# penilaian : nilai
# work : work
# alhmdllah : alhmdllah
# pola : pola
# bermasyarakat : masyarakat
# pemakaiannya : pakai
# menggangu : menggangu
# 7q : 7q
# sertivicate : sertivicate
# supplier : supplier
# listnya : listnya
# wajah : wajah
# pemilik : milik
# accout : accout
# pinjam : pinjam
# account : account
# kebaikan : baik
# bergunalah : guna
# hidupmu : hidup
# senin : senin
# yklau : yklau
# sirtifikat : sirtifikat
# nykedua : nykedua
# melakulan : melakulan
# pertamanyabaru : pertamanyabaru
# ganggu : ganggu
# notifikasinya : notifikasi
# notifnya : notifnya
# sahabat : sahabat
# ataopun : ataopun
# agreenya : agreenya
# insyaallah : insyaallah
# kometmen : kometmen
# wujud : wujud
# iman : iman
# subhanahuwataala : subhanahuwataala
# individu : individu
# penyebab : sebab
# best : best
# yuk : yuk
# plastik : plastik
# bye : bye
# dada : dada
# canda : canda
# wwkwkk : wwkwkk
# kakka : kakka
# ngegunain : ngegunain
# membatu : batu
# pademi : pademi
# set : set
# kecilbro : kecilbro
# pedulilindungiutk : pedulilindungiutk
# bertanggungjawab : bertanggungjawab
# bacasaya : bacasaya
# alpikasinya : alpikasinya
# bukasedangkan : bukasedangkan
# onlineape : onlineape
# syuka : syuka
# sngat : sngat
# prosesnya : proses
# pertahankan : tahan
# bangetsaya : bangetsaya
# sayathanks : sayathanks
# mengajak : ajak
# valsinasi : valsinasi
# menjaga : jaga
# lingkunan : lingkunan
# tetangga : tetangga
# lari : lari
# thnx : thnx
# kmna : kmna
# lembaran : lembar
# lecek : lecek
# caci : caci
# maki : maki
# netizen : netizen
# bebas : bebas
# membuktikan : bukti
# bermutu : mutu
# bodh : bodh
# ketama : ketama
# sekararang : sekararang
# vertifikasi : vertifikasi
# kemanapun : mana
# updatingnya : updatingnya
# disekitar : sekitar
# alhamdullillah : alhamdullillah
# kawatir : kawatir
# jospelayanan : jospelayanan
# punyabisa : punyabisa
# detail : detail
# sederhana : sederhana
# kaum : kaum
# pensiunan : pensiun
# membukanya : buka
# laki : laki
# ucapkan : ucap
# terimah : terimah
# ngeluh : ngeluh
# disinidan : disinidan
# adadan : adad
# penguduhan : uduh
# sertifikatsangat : sertifikatsangat
# flash : flash
# efort : efort
# pedulilimdungi : pedulilimdungi
# kovid : kovid
# berahir : berahir
# terkendali : kendali
# mencegahnya : cegah
# mengobatinya : obat
# saudara2ku : saudara2ku
# hardcopy : hardcopy
# bersyukur : syukur
# dngn : dngn
# terbapus : terbapus
# melindungi : lindung
# asalamu : asalamu
# alaikum : alaikum
# nyh : nyh
# kecillan : kecillan
# bismillahirahmannirahim : bismillahirahmannirahim
# swt : swt
# mantul : mantul
# sumber : sumber
# penggunaanyaberbeda : penggunaanyaberbeda
# lm : lm
# srt : srt
# petugasnya : tugas
# puji : puji
# 28oct21 : 28oct21
# nyagimana : nyagimana
# melewati : lewat
# kokbagus : kokbagus
# pahaminbismillah : pahaminbismillah
# kerjaanjadi : kerjaanjadi
# babu : babu
# bismillah : bismillah
# administrasi : administrasi
# outnya : outnya
# bunyi : bunyi
# hee : hee
# heesetelah : heesetelah
# solusinyaterima : solusinyaterima
# ngatasi : ngatasi
# kontrol : kontrol
# kepatuhan : patuh
# membatuknapa : membatuknapa
# okmantapmulai : okmantapmulai
# canggihsemua : canggihsemua
# aplikasiinimaju : aplikasiinimaju
# bangga : bangga
# plosok2 : plosok2
# pedulia : pedulia
# mengetahuinnya : mengetahuinnya
# appl : appl
# setifikat : setifikat
# ngambang : ngambang
# batre : batre
# munculdiaplikasi : munculdiaplikasi
# okelah : oke
# ngebntu : ngebntu
# mengawal : awal
# new : new
# penggunaanya : penggunaanya
# terimakasihsalam : terimakasihsalam
# indonesiaku : indonesia
# tangguh : tangguh
# kendalalebih : kendalalebih
# updatehmm : updatehmm
# nomornya : nomor
# bukatrima : bukatrima
# koneksinya : koneksi
# aplikaai : aplikaai
# dipahamisertifikasinya : dipahamisertifikasinya
# adatapi : adatapi
# sertifikasinya : sertifikasi
# visa : visa
# samakan : sama
# autocheckout : autocheckout
# janji : janji
# pemakai : pakai
# joos : joos
# luarbiasa : luarbiasa
# ajalah : aja
# ketahuan : tahu
# nakalnya : nakal
# suksesselalu : suksesselalu
# desainya : desa
# bagusjd : bagusjd
# fiturnya : fiturnya
# fullwalaupun : fullwalaupun
# membantudalam : membantudalam
# dalamsetiap : dalamsetiap
# dipahami : paham
# terunduh : unduh
# dubuka : dubuka
# passudah : passudah
# kebutuhan : butuh
# load : load
# susahngak : susahngak
# berkat : berkat
# indonsia : indonsia
# satgas : satgas
# candirenggo : candirenggo
# memproses : proses
# kon : kon
# memutus : putus
# rantai : rantai
# penularan : tular
# aplikasinyamohon : aplikasinyamohon
# keluat : luat
# berkah : berkah
# yra : yra
# memerivikasi : memerivikasi
# telfon : telfon
# pergipergian : pergipergian
# kmnapun : kmnapun
# masukslalu : masukslalu
# top : top
# bagas : bagas
# oksemoga : oksemoga
# sistemnta : sistemnta
# lncar : lncar
# kerenlah : keren
# negara2 : negara2
# akhiranya : akhiranya
# seru : seru
# kejut : kejut
# pedulilindunginya : pedulilindunginya
# nyalangsung : nyalangsung
# gelari : gelar
# kita : kita
# vaksinsmg : vaksinsmg
# covid19amin : covid19amin
# tempat : tempat
# kendor : kendor
# bagusadmin : bagusadmin
# ramahmantab : ramahmantab
# alhmdulillh : alhmdulillh
# oksertifikat : oksertifikat
# pokok : pokok
# aplikasiani : aplikasiani
# kerenpelayanan : kerenpelayanan
# v1 : v1
# v2 : v2
# allhmdullh : allhmdullh
# setivikat : setivikat
# mamamu : mama
# utamakan : utama
# bisakeluar : bisakeluar
# barkoct : barkoct
# menjalankannya : jalan
# imdonesia : imdonesia
# mmudahkan : mmudahkan
# bpergian : bpergian
# piknik : piknik
# cide : cide
# yea : yea
# natri : natri
# bolpein : bolpein
# operasi : operasi
# apresiasi : apresiasi
# barkotnya : barkotnya
# digunakantrims : digunakantrims
# adminsaya : adminsaya
# start : start
# cangung : cangung
# bantuanx : bantuanx
# infi : infi
# ttng : ttng
# dimiliki : milik
# menunjang : tunjang
# nahklo : nahklo
# ngedaptat : ngedaptat
# pedulilindunggi : pedulilindunggi
# trimaksih : trimaksih
# situasi : situasi
# cobid : cobid
# sakti : sakti
# puya : puya
# tertanggung : tanggung
# pedulipelinding : pedulipelinding
# ingatkan : ingat
# dimanfaatkan : manfaat
# serfifikat : serfifikat
# dah : dah
# bagussaya : bagussaya
# kenerja : kenerja
# aktiv : aktiv
# oktapi : oktapi
# tranparansi : tranparansi
# denali : denali
# says : says
# menyukai : suka
# dengn : dengn
# pedulilindungibagus : pedulilindungibagus
# aktiffitas : aktiffitas
# ausah : ausah
# yamohon : yamohon
# sangan : sangan
# dipaksin : dipaksin
# gemilang : gemilang
# dj : dj
# mantapsudah : mantapsudah
# benarbenardiri : benarbenardiri
# bertamu : tamu
# dek : dek
# andin : andin
# mantab : mantab
# semog : semog
# sagab : sagab
# serti : serti
# fikat : fikat
# llndung : llndung
# nnya : nnya
# bagusmudah : bagusmudah
# monitor : monitor
# pengenal : kenal
# certifikat : certifikat
# memcega : memcega
# berbicara : bicara
# susesek : susesek
# aflikadi : aflikadi
# lslu : lslu
# aplikasinyaa : aplikasinyaa
# mamtap : mamtap
# kereenakurat : kereenakurat
# bermanpaat : bermanpaat
# menolong : tolong
# terdebest : terdebest
# menguntungkan : untung
# mantapdan : mantapdan
# okterima : okterima
# kantong : kantong
# 9a : 9a
# {'scan': 'scan', 'qr': 'qr', 'code': 'code', 'lobby': 'lobby', 'kantor': 'kantor', 'pagitetapi': 'pagitetapi', 'aplikasi': 'aplikasi', 'errorscan': 'errorscan', 'melebihi': 'lebih', 'radius': 'radius', 'error': 'error', 'diupdate': 'diupdate', 'versi': 'versi', 'terbaru': 'baru', 'dibuka': 'buka', 'bolak': 'bolak', 'force': 'force', 'close': 'close', 'sayangnya': 'sayang', 'pedulilindungi': 'pedulilindungi', 'berhenti': 'henti', 'coba': 'coba', 'uninstal': 'uninstal', 'instal': 'instal', 'hasilnya': 'hasil', 'akun': 'akun', 'vaksin': 'vaksin', '1': '1', '2': '2', 'begini': 'begini', 'nyusahkan': 'nyusahkan', 'masyarakat': 'masyarakat', 'repot': 'repot', 'aplikasinya': 'aplikasi', 'perbaiki': 'baik', 'masak': 'masak', 'beli': 'beli', 'hape': 'hape', 'gara': 'gara', 'centangan': 'centangan', 'setuju': 'tuju', 'diam': 'diam', 'respon': 'respon', 'hp': 'hp', 'teman': 'teman', 'diperbaiki': 'baik', 'dipakai': 'pakai', 'seindonesia': 'indonesia', 'ganti': 'ganti', 'makan': 'makan', 'susah': 'susah', 'rakyat': 'rakyat', 'urgent': 'urgent', 'android': 'android', 'dibawah': 'bawah', '6': '6', 'support': 'support', 'pakai': 'pakai', '5': '5', 'berat': 'berat', 'pemerintah': 'perintah', 'sumbang': 'sumbang', 'downlod': 'downlod', 'centa': 'centa', 'setujutapi': 'setujutapi', 'maksudnya': 'maksud', 'kemarin': 'kemarin', 'pergi2': 'pergi2', 'check': 'check', 'barcode': 'barcode', 'maunya': 'mau', 'peduli': 'peduli', 'lindung': 'lindung', 'pilihan': 'pilih', 'warga': 'warga', 'negara': 'negara', 'klik': 'klik', 'wni': 'wni', 'centang': 'centang', 'syarat': 'syarat', 'penggunaan': 'guna', 'kebijakan': 'bijak', 'privasi': 'privasi', 'selanjutnnya': 'selanjutnnya', 'apapun': 'apa', 'mengulangi': 'ulang', 'hasil': 'hasil', 'uninstall': 'uninstall', 'solusinya': 'solusi', 'mengunjungi': 'unjung', 'mengharuskan': 'harus', 'login': 'login', 'semejak': 'semejak', 'diwajibkan': 'wajib', 'busway': 'busway', 'terbuang': 'buang', 'sampah': 'sampah', 'memperlambat': 'lambat', 'menghambat': 'hambat', 'menyusahkan': 'susah', 'merepotkan': 'repot', 'menyebalkan': 'sebal', 'benarbenar': 'benarbenar', 'mempersulit': 'sulit', 'sertifikat': 'sertifikat', 'muncul': 'muncul', 'gembel': 'gembel', 'buka': 'buka', 'pas': 'pas', 'pilih': 'pilih', 'kenegaraan': 'negara', 'ikuti': 'ikut', 'langkah': 'langkah', 'ceklis': 'ceklis', 'tombol': 'tombol', 'geser': 'geser', 'suport': 'suport', 'penjelasannya': 'jelas', 'mengalami': 'alami', 'kenadala': 'kenadala', 'log': 'log', 'layar': 'layar', 'tujuan': 'tuju', 'memudahkan': 'mudah', 'pekerjaan': 'kerja', 'serius': 'serius', 'tolong': 'tolong', 'perhatikan': 'perhati', 'sudut': 'sudut', 'pandang': 'pandang', 'konsumen': 'konsumen', 'meninggalkannya': 'tinggal', 'maksud': 'maksud', 'gagal': 'gagal', 'penyampaian': 'sampai', 'buruk': 'buruk', 'terima': 'terima', 'kasih': 'kasih', 'download': 'download', 'baikbaik': 'baikbaik', 'kesalahan': 'salah', 'terhapus': 'hapus', 'lindungi': 'lindung', 'kok': 'kok', 'scroll': 'scroll', 'diulang': 'ulang', 'keadaannya': 'ada', 'enggak': 'enggak', 'mempermudah': 'mudah', 'errornya': 'errornya', 'banding': 'banding', 'berhasilnya': 'hasil', 'location': 'location', 'aktif': 'aktif', 'sesuai': 'sesuai', 'titik': 'titik', 'sudah': 'sudah', 'dari': 'dari', 'becanda': 'becanda', 'sebel': 'sebel', 'pagi': 'pagi', 'dibikin': 'bikin', 'setres': 'tres', 'gegara': 'gegara', 'masuk': 'masuk', 'gedung': 'gedung', 'terhambat': 'hambat', 'karena': 'karena', 'mulu': 'mulu', 'infokan': 'info', 'otomatis': 'otomatis', 'wifi': 'wifi', 'sertitikat': 'sertitikat', 'apkikasi': 'apkikasi', 'email': 'email', 'format': 'format', 'permohonan': 'mohon', 'sertivikat': 'sertivikat', 'infonya': 'info', 'proses': 'proses', 'silakan': 'sila', 'menghubungi': 'hubung', 'penyelenggara': 'selenggara', 'menubggu': 'menubggu', 'hubungi': 'hubung', 'wewenangnya': 'wewenangnya', 'daa': 'daa', 'install': 'install', 'membutuhkan': 'butuh', 'membuka': 'buka', 'ribet': 'ribet', 'evisien': 'evisien', 'mending': 'mending', 'penumpan ...
# ------------------------
# Pandas Apply:   0%|          | 0/1945 [00:00<?, ?it/s]

# %%
df_skripsi
# Out:
#                                               text_real  \
# 0     Biasanya saya scan QR code di lobby kantor set...
# 1     Setelah di-update versi terbaru kok malah gak ...
# 2     Sekarang Update terbaru malah ga bisa masuk ad...
# 3     Gimana ini aplikasi kok gak bisa di gunakan. S...
# 4     Sebelumnya ada pilihan warga negara, saya suda...
# ...                                                 ...
# 1943                               aku gak bis masuknya
# 1944                                  Ko gx bisa login.
# 1945                                 Koq gak mau kebuka
# 1946                                 Semoga sehat semua
# 1947                                sangat membantu,, 👍
#
#                                                    text     label  \
# 0     biasanya saya scan qr code di lobby kantor set...  Negative
# 1     setelah diupdate versi terbaru kok malah gak b...  Negative
# 2     sekarang update terbaru malah ga bisa masuk ad...  Negative
# 3     gimana ini aplikasi kok gak bisa di gunakan sa...  Negative
# 4     sebelumnya ada pilihan warga negara saya sudah...  Negative
# ...                                                 ...       ...
# 1943                               aku gak bis masuknya  Negative
# 1944                                   ko gx bisa login  Negative
# 1945                                 koq gak mau kebuka  Negative
# 1946                                 semoga sehat semua  Positive
# 1947                                    sangat membantu  Positive
#
#                                             text_tokens  \
# 0     [biasanya, saya, scan, qr, code, di, lobby, ka...
# 1     [setelah, diupdate, versi, terbaru, kok, malah...
# 2     [sekarang, update, terbaru, malah, ga, bisa, m...
# 3     [gimana, ini, aplikasi, kok, gak, bisa, di, gu...
# 4     [sebelumnya, ada, pilihan, warga, negara, saya...
# ...                                                 ...
# 1943                          [aku, gak, bis, masuknya]
# 1944                              [ko, gx, bisa, login]
# 1945                            [koq, gak, mau, kebuka]
# 1946                             [semoga, sehat, semua]
# 1947                                 [sangat, membantu]
#
#                                         text_tokens_WSW  \
# 0     [scan, qr, code, lobby, kantor, pagitetapi, ap...
# 1     [diupdate, versi, terbaru, dibuka, bolak, forc...
# 2     [terbaru, centangan, setuju, diam, respon, hp,...
# 3     [aplikasi, downlod, centa, setujutapi, maksudn...
# 4     [pilihan, warga, negara, klik, wni, centang, s...
# ...                                                 ...
# 1943                                    [bis, masuknya]
# 1944                                    [ko, gx, login]
# 1945                                      [koq, kebuka]
# 1946                                    [semoga, sehat]
# 1947                                         [membantu]
#
#                                       text_tokens_fdist  \
# 0     {'biasanya': 1, 'saya': 1, 'scan': 1, 'qr': 2,...
# 1     {'setelah': 1, 'diupdate': 1, 'versi': 1, 'ter...
# 2     {'sekarang': 1, 'update': 1, 'terbaru': 1, 'ma...
# 3     {'gimana': 2, 'ini': 2, 'aplikasi': 1, 'kok': ...
# 4     {'sebelumnya': 1, 'ada': 3, 'pilihan': 1, 'war...
# ...                                                 ...
# 1943      {'aku': 1, 'gak': 1, 'bis': 1, 'masuknya': 1}
# 1944          {'ko': 1, 'gx': 1, 'bisa': 1, 'login': 1}
# 1945        {'koq': 1, 'gak': 1, 'mau': 1, 'kebuka': 1}
# 1946              {'semoga': 1, 'sehat': 1, 'semua': 1}
# 1947                       {'sangat': 1, 'membantu': 1}
#
#                                         text_normalized  \
# 0     [scan, qr, code, lobby, kantor, pagitetapi, ap...
# 1     [diupdate, versi, terbaru, dibuka, bolak, forc...
# 2     [terbaru, centangan, setuju, diam, respon, hp,...
# 3     [aplikasi, downlod, centa, setujutapi, maksudn...
# 4     [pilihan, warga, negara, klik, wni, centang, s...
# ...                                                 ...
# 1943                                    [bis, masuknya]
# 1944                               [kok, enggak, login]
# 1945                                      [kok, kebuka]
# 1946                                    [semoga, sehat]
# 1947                                         [membantu]
#
#                                     text_tokens_stemmed
# 0     [scan, qr, code, lobby, kantor, pagitetapi, ap...
# 1     [diupdate, versi, baru, buka, bolak, force, cl...
# 2     [baru, centangan, tuju, diam, respon, hp, tema...
# 3     [aplikasi, downlod, centa, setujutapi, maksud,...
# 4     [pilih, warga, negara, klik, wni, centang, tuj...
# ...                                                 ...
# 1943                                       [bis, masuk]
# 1944                               [kok, enggak, login]
# 1945                                        [kok, buka]
# 1946                                      [moga, sehat]
# 1947                                            [bantu]
#
# [1945 rows x 8 columns]

# %% [markdown]
# # Menampilkan kembali gabungan data

# %%
def merge_again(text):
    return ' '.join(text)

# %%
df_skripsi['done_text'] = df_skripsi['text_tokens_stemmed'].apply(merge_again)
df_skripsi
# Out:
#                                               text_real  \
# 0     Biasanya saya scan QR code di lobby kantor set...
# 1     Setelah di-update versi terbaru kok malah gak ...
# 2     Sekarang Update terbaru malah ga bisa masuk ad...
# 3     Gimana ini aplikasi kok gak bisa di gunakan. S...
# 4     Sebelumnya ada pilihan warga negara, saya suda...
# ...                                                 ...
# 1943                               aku gak bis masuknya
# 1944                                  Ko gx bisa login.
# 1945                                 Koq gak mau kebuka
# 1946                                 Semoga sehat semua
# 1947                                sangat membantu,, 👍
#
#                                                    text     label  \
# 0     biasanya saya scan qr code di lobby kantor set...  Negative
# 1     setelah diupdate versi terbaru kok malah gak b...  Negative
# 2     sekarang update terbaru malah ga bisa masuk ad...  Negative
# 3     gimana ini aplikasi kok gak bisa di gunakan sa...  Negative
# 4     sebelumnya ada pilihan warga negara saya sudah...  Negative
# ...                                                 ...       ...
# 1943                               aku gak bis masuknya  Negative
# 1944                                   ko gx bisa login  Negative
# 1945                                 koq gak mau kebuka  Negative
# 1946                                 semoga sehat semua  Positive
# 1947                                    sangat membantu  Positive
#
#                                             text_tokens  \
# 0     [biasanya, saya, scan, qr, code, di, lobby, ka...
# 1     [setelah, diupdate, versi, terbaru, kok, malah...
# 2     [sekarang, update, terbaru, malah, ga, bisa, m...
# 3     [gimana, ini, aplikasi, kok, gak, bisa, di, gu...
# 4     [sebelumnya, ada, pilihan, warga, negara, saya...
# ...                                                 ...
# 1943                          [aku, gak, bis, masuknya]
# 1944                              [ko, gx, bisa, login]
# 1945                            [koq, gak, mau, kebuka]
# 1946                             [semoga, sehat, semua]
# 1947                                 [sangat, membantu]
#
#                                         text_tokens_WSW  \
# 0     [scan, qr, code, lobby, kantor, pagitetapi, ap...
# 1     [diupdate, versi, terbaru, dibuka, bolak, forc...
# 2     [terbaru, centangan, setuju, diam, respon, hp,...
# 3     [aplikasi, downlod, centa, setujutapi, maksudn...
# 4     [pilihan, warga, negara, klik, wni, centang, s...
# ...                                                 ...
# 1943                                    [bis, masuknya]
# 1944                                    [ko, gx, login]
# 1945                                      [koq, kebuka]
# 1946                                    [semoga, sehat]
# 1947                                         [membantu]
#
#                                       text_tokens_fdist  \
# 0     {'biasanya': 1, 'saya': 1, 'scan': 1, 'qr': 2,...
# 1     {'setelah': 1, 'diupdate': 1, 'versi': 1, 'ter...
# 2     {'sekarang': 1, 'update': 1, 'terbaru': 1, 'ma...
# 3     {'gimana': 2, 'ini': 2, 'aplikasi': 1, 'kok': ...
# 4     {'sebelumnya': 1, 'ada': 3, 'pilihan': 1, 'war...
# ...                                                 ...
# 1943      {'aku': 1, 'gak': 1, 'bis': 1, 'masuknya': 1}
# 1944          {'ko': 1, 'gx': 1, 'bisa': 1, 'login': 1}
# 1945        {'koq': 1, 'gak': 1, 'mau': 1, 'kebuka': 1}
# 1946              {'semoga': 1, 'sehat': 1, 'semua': 1}
# 1947                       {'sangat': 1, 'membantu': 1}
#
#                                         text_normalized  \
# 0     [scan, qr, code, lobby, kantor, pagitetapi, ap...
# 1     [diupdate, versi, terbaru, dibuka, bolak, forc...
# 2     [terbaru, centangan, setuju, diam, respon, hp,...
# 3     [aplikasi, downlod, centa, setujutapi, maksudn...
# 4     [pilihan, warga, negara, klik, wni, centang, s...
# ...                                                 ...
# 1943                                    [bis, masuknya]
# 1944                               [kok, enggak, login]
# 1945                                      [kok, kebuka]
# 1946                                    [semoga, sehat]
# 1947                                         [membantu]
#
#                                     text_tokens_stemmed  \
# 0     [scan, qr, code, lobby, kantor, pagitetapi, ap...
# 1     [diupdate, versi, baru, buka, bolak, force, cl...
# 2     [baru, centangan, tuju, diam, respon, hp, tema...
# 3     [aplikasi, downlod, centa, setujutapi, maksud,...
# 4     [pilih, warga, negara, klik, wni, centang, tuj...
# ...                                                 ...
# 1943                                       [bis, masuk]
# 1944                               [kok, enggak, login]
# 1945                                        [kok, buka]
# 1946                                      [moga, sehat]
# 1947                                            [bantu]
#
#                                               done_text
# 0     scan qr code lobby kantor pagitetapi aplikasi ...
# 1     diupdate versi baru buka bolak force close say...
# 2     baru centangan tuju diam respon hp teman baik ...
# 3     aplikasi downlod centa setujutapi maksud kemar...
# 4     pilih warga negara klik wni centang tuju syara...
# ...                                                 ...
# 1943                                          bis masuk
# 1944                                   kok enggak login
# 1945                                           kok buka
# 1946                                         moga sehat
# 1947                                              bantu
#
# [1945 rows x 9 columns]

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %%
tfid = TfidfVectorizer(
    min_df = 3,
    max_df = 0.10,
    ngram_range = (1,2)
)

# %%
count_vect = CountVectorizer(
    min_df = 3,
    max_df = 0.10,
    ngram_range = (1,2)
)

# %%
tfid_result = tfid.fit_transform(df_skripsi["done_text"]).toarray()
tfid_df = pd.DataFrame(tfid_result, columns = tfid.get_feature_names())
tfid_df.columns = ["word_" + str(x) for x in tfid_df.columns]
tfid_df.index = df_skripsi.index
# new_data = pd.concat([, tfid_df], axis=1)

# %%
tfid_df.columns
# Out:
# Index(['word_10', 'word_119', 'word_12', 'word_19', 'word_2021', 'word_23',
#        'word_23 oktober', 'word_24', 'word_26', 'word_26 oktober',
#        ...
#        'word_wisata', 'word_wna', 'word_wni', 'word_wni centang',
#        'word_wni muncul', 'word_wni wna', 'word_wniwna', 'word_xiaomi',
#        'word_yapadahal', 'word_zona'],
#       dtype='object', length=1593)

# %%
cvzr_result = count_vect.fit_transform(df_skripsi["done_text"]).toarray()
cvzr_df = pd.DataFrame(cvzr_result, columns = count_vect.get_feature_names())
cvzr_df.columns = ["word_" + str(x) for x in cvzr_df.columns]
cvzr_df.index = df_skripsi.index
# new_data = pd.concat([, tfid_df], axis=1)

# %% [markdown]
# # Menampilkan label kolom

# %%
kolomcv = cvzr_df.columns
kolomcv
# Out:
# Index(['word_10', 'word_119', 'word_12', 'word_19', 'word_2021', 'word_23',
#        'word_23 oktober', 'word_24', 'word_26', 'word_26 oktober',
#        ...
#        'word_wisata', 'word_wna', 'word_wni', 'word_wni centang',
#        'word_wni muncul', 'word_wni wna', 'word_wniwna', 'word_xiaomi',
#        'word_yapadahal', 'word_zona'],
#       dtype='object', length=1593)

# %% [markdown]
# # Menampilkan Hasil classification

# %%
y = df_skripsi.label

# %%
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(clf, X, y, cv=5)
conf_mat = confusion_matrix(y_pred, y)

# %%
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# [[1350  160]
#  [ 117  318]]
#               precision    recall  f1-score   support
#
#     Negative     0.8940    0.9202    0.9070      1467
#     Positive     0.7310    0.6653    0.6966       478
#
#     accuracy                         0.8576      1945
#    macro avg     0.8125    0.7928    0.8018      1945
# weighted avg     0.8540    0.8576    0.8553      1945

# %%
print('SVM')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(svm, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# SVM
# [[1394  180]
#  [  73  298]]
#               precision    recall  f1-score   support
#
#     Negative     0.8856    0.9502    0.9168      1467
#     Positive     0.8032    0.6234    0.7020       478
#
#     accuracy                         0.8699      1945
#    macro avg     0.8444    0.7868    0.8094      1945
# weighted avg     0.8654    0.8699    0.8640      1945

# %%
print('SVM')
X = tfid_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(svm, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# SVM
# [[1444  190]
#  [  23  288]]
#               precision    recall  f1-score   support
#
#     Negative     0.8837    0.9843    0.9313      1467
#     Positive     0.9260    0.6025    0.7300       478
#
#     accuracy                         0.8905      1945
#    macro avg     0.9049    0.7934    0.8307      1945
# weighted avg     0.8941    0.8905    0.8818      1945

# %% [markdown]
# # Menampilkan hasil Decision Tree

# %%
print('Naive Bayes')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(nb, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# Naive Bayes
# [[1293  165]
#  [ 174  313]]
#               precision    recall  f1-score   support
#
#     Negative     0.8868    0.8814    0.8841      1467
#     Positive     0.6427    0.6548    0.6487       478
#
#     accuracy                         0.8257      1945
#    macro avg     0.7648    0.7681    0.7664      1945
# weighted avg     0.8268    0.8257    0.8263      1945

# %%
print('Naive Bayes')
X = tfid_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(nb, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# Naive Bayes
# [[1294  166]
#  [ 173  312]]
#               precision    recall  f1-score   support
#
#     Negative     0.8863    0.8821    0.8842      1467
#     Positive     0.6433    0.6527    0.6480       478
#
#     accuracy                         0.8257      1945
#    macro avg     0.7648    0.7674    0.7661      1945
# weighted avg     0.8266    0.8257    0.8261      1945

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
SemuaText = "".join(df_skripsi['done_text'])

def create_wordcloud(text, filename): 
    stopwords = set(STOPWORDS)

    wc = WordCloud(background_color="white",
                   max_words=200,
                   stopwords=stopwords)

    wc.generate(text)
    wc.to_file(filename+".png")
    plt.figure()
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
SemuaText
# Out:
# 'scan qr code lobby kantor pagitetapi aplikasi errorscan qr code lebih radius errordiupdate versi baru buka bolak force close sayang pedulilindungi henti coba uninstal instal hasil bolak hasil akun vaksin 1 2 begini nyusahkan masyarakat scan qr repot aplikasi buka baik aplikasi masak beli hape masak gara gara pedulilindungi bukabaru centangan tuju diam respon hp teman baik aplikasi pakai indonesia masak ganti hp makan susah rakyat urgent baik android bawah 6 support hp pakai android 6 5 berat beli hp perintah sumbang hpaplikasi downlod centa setujutapi maksud kemarin pergi2 check barcode mau peduli lindung pedulipilih warga negara klik wni centang tuju syarat guna bijak privasi selanjutnnya apa ulang 5 hasil apa uninstall instal aplikasi pedulilindungi solusi scan barcode unjung harus login pedulilindungi solusisemejak aplikasi wajib busway buang aplikasi sampah lambat hambat susah repot sebal aplikasi benarbenar sulit check susah sertifikat muncul aplikasi gembelhp login coba klik buka aplikasi pas pilih warga negara ikut langkah langkah pas klik ceklis tombol tuju bawah geser klik geser hp suport aplikasi jelasalami kenadala log layar hp versi android baru baik tuju aplikasi mudah kerja serius aplikasi tolong perhati sudut pandang konsumen aplikasi tinggal maksud gagal sampai buruk terima kasihdownload aplikasi baikbaik salah aplikasi hp hapus peduli lindung download klik tuju kok scroll ulang download aplikasi hp ada solusienggak aplikasi mudah sulit errornya banding hasil radius location aktif sesuai titik sudah dari 6 sertifikat enggak aplikasi becanda sebel pagi bikin tres gegara masuk gedung hambat karena aplikasi error mulu info aplikasi hp otomatis pakai wifi aplikasi2 vaksin sertitikat muncul apkikasi email sesuai format mohon sertivikat info proses sila hubung selenggara vaksin menubggu muncul hubung selenggara vaksin wewenangnya aplikasi uninstall daa installbutuh buka aplikasi ribet enggak evisien mending tumpang mes tiket kereta transportasi vaksin pcrantigen belumotamatis data vaksin dsb beli tiket cepat enggak ribetbobrok malu app kelas menteri kait begini komplain masuk tanggal lahir app buka begini wacana dompet digital haallo sehat niehparah bagus aplikasi jelek semenjak paksa log out log kove verifikasi otp banget via email via hp tetap lot pas sesi tunggu 3 jam parah vaksin 2 ribet sumpah kesel bangetaplikasi pedulilindungi upgrade versi susah buka aplikasi tunggu nomor verifikasi sekali nomor langsunh menu suruh tunggu 3 jam maksud tolong bantukecewa app login tekan hp sudah coba scroll bawah keluar beli hp android layar pakai app initolong baik aplikasi karena begini mana pakai app lihat barcode loginreset hp instal pedulilindungi playstore pilih wni muncul syarat guna bijak privasi inti diceklis tuju ceklis notifikasi apa sulit publik place fasilitas scan qr apl pedulindungi solusi terima kasihhp android ver6 akses apk pedulilindungi ver7 atas senjang sosial rakyat hp bagus tolong tindak hambat aktifitas apk tolong perhatitolong tolong app pakai nik begitu kakek2 nenek hp akses otomatis bantu 1 hp 1 akun 1 akun bantu nik kakek nenek 1 keluarga hp 1 rakyat mu kayak kayak dihidupin 10 anggota keluarga gaji gede bijak thanksvaksin sertifikat vaksin hubung puskesmas jadwal vaksin suami daftar suamisertifikat vaksin 1 2 terang vaksin dilogout kali input data nik hp moga baik aplikasi krusial pergijelek login login login nomor telepon sesuai kode otp kirim kode otp niat aplikasi susah masyarakat aplikasiasih bintang jelek aplikasi play store aplikasi padahal sistem begini pilih wni centang hp enggak muncul tulis tuju enggak discroll baca balas ulas play store suruh android versi 70 padahal android ver baru tetap enggak baikassalamualaikum selamat pagi tolong baik aplikasi peduli lindung mana gara gara aplikasi jalan daftar susah coba profesional aplikasi cangkup juta membuag kesal kendala aplikasi log selamat asal baikbenar faksin 1 2 sertifikat muncul bolak coba muncul nik nama benar hadehh kendala kayak tol ...

# %%
create_wordcloud(SemuaText,"Semua Sentimen")

# %%
komenpositif= df_skripsi[df_skripsi['label'] == "Positive"]

# %%
Positive = "".join(komenpositif['done_text'])

def create_wordcloud(text, filename): 
    stopwords = set(STOPWORDS)

    wc = WordCloud(background_color="white",
                   max_words=200,
                   stopwords=stopwords)

    wc.generate(text)
    wc.to_file(filename+".png")
    plt.figure()
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
create_wordcloud(Positive,"Semua Positive")

# %%
komennegatif= df_skripsi[df_skripsi['label'] == "Negative"]

# %%
Negative = "".join(komennegatif['done_text'])

def create_wordcloud(text, filename): 
    stopwords = set(STOPWORDS)

    wc = WordCloud(background_color="white",
                   max_words=200,
                   stopwords=stopwords)

    wc.generate(text)
    wc.to_file(filename+".png")
    plt.figure()
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
create_wordcloud(Negative,"Semua Negative")
